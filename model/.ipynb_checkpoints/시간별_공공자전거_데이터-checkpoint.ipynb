# %%
import pandas as pd

# %% [markdown]
# ### 진행해야할 사항
# - 컬럼 정리 -> 필요없는 컬럼 우선 제거 "대여구분코드", "성별", "운동량", "탄소량"
# - "대여일자" 컬럼 "연도", "월", "일" 컬럼으로 나눌 필요가 있음
# - "대여소명" 컬럼 "대여소번호" 와 "대여소"로 나눌 필요 있음
# - 각 항목에 필요한 데이터 파일을 분리할 필요가 있음
#
# #### 데이터 항목
# - 2025년 월별 이용 추이
# - 인기 대여소 6곳
# - 연령대별 이용 비율
# - 당장은 이렇게 세 개의 데이터

# %%
df1 = pd.read_csv('data/time/서울특별시 공공자전거 이용정보(시간대별)_202508.csv')
df1.head()
# Out:
#          대여일자  대여시간  대여소번호                 대여소명 대여구분코드   성별 연령대코드  이용건수  \
# 0  2025-07-01     0   1293    1293. 석촌호수 서호 사거리    정기권  NaN  ~10대     1
# 1  2025-07-01     0    739           739. 신월사거리    정기권  NaN   20대     1
# 2  2025-07-01     0    505  505. 자양사거리 광진아크로텔 앞    정기권  NaN   20대     2
# 3  2025-07-01     0   1529     1529. 미아동 한국전력공사    정기권  NaN   20대     1
# 4  2025-07-01     0   1650        1650. 중계근린공원내    정기권  NaN   20대     2
#
#      운동량   탄소량  이동거리(M)  이용시간(분)
# 0  15.83  0.14   615.10        5
# 1   9.81  0.09   381.15        4
# 2  31.36  0.33  1393.80        8
# 3  79.58  0.72  3091.62       16
# 4  76.78  0.69  2982.88       38

# %%
df_top.to_csv('data/월별_대여소별_공공자전거_이용건수_전체.csv', index=False, encoding='utf-8-sig')

print('데이터 저장 완료!')
# Out:
# 데이터 저장 완료!

# %%
for month in range(1, 7):
    
    # 파일 경로
    file = f'data/time/서울특별시 공공자전거 이용정보(시간대별)_2025{month:02d}.csv'
    
    # CSV 불러오기
    df = pd.read_csv(file)

    # 대여소번호와 대여소 분리
    df[['대여소번호', '대여소']] = df['대여소명'].str.extract(
        r'^(\d+)\.\s*(.*)$'
    )

    # 대여소번호 숫자 변환
    df['대여소번호'] = pd.to_numeric(
        df['대여소번호'],
        errors='coerce'
    )

    # 대여소 이름 공백 제거
    df['대여소'] = df['대여소'].str.strip()

    # 날짜 변환
    df['대여일자'] = pd.to_datetime(
        df['대여일자'],
        errors='coerce'
    )

    # 연도 / 월 / 일 분리
    df['연도'] = df['대여일자'].dt.year
    df['월'] = df['대여일자'].dt.month
    df['일'] = df['대여일자'].dt.day

    # 원하는 컬럼 순서
    cols = ['연도', '월', '일'] + [
        col for col in df.columns
        if col not in ['연도', '월', '일']
    ]

    df = df[cols]

    # 불필요한 컬럼 삭제
    df = df.drop(
        ['대여소명', '대여일자', '대여구분코드', '성별', '운동량', '탄소량'],
        axis=1
    )

    # 대여소번호 정수형 변환
    df['대여소번호'] = df['대여소번호'].astype('Int64')

    # 대여소번호 결측치 제거
    df = df.dropna(subset=['대여소번호'])

    # 컬럼 이름 변경
    df = df.rename(columns={'이동거리': '이동거리(M)'})

    # # 대여소별 이용건수 합계
    # df = (
    #     df.groupby(
    #         ['연도', '월', '대여소번호', '대여소'],
    #         as_index=False
    #     )['이용건수']
    #     .sum()
    #     .reset_index(drop=True)
    # )

    # df_202501, df_202502 ... 형태로 저장
    globals()[f'df_2025{month:02d}'] = df

# %%
df_202501.head(10)
# Out:
#      연도  월  일  대여시간  대여소번호 연령대코드  이용건수     이동거리                대여소
# 0  2025  1  1     0   3684  ~10대     1  4730.80       고덕자이(105동 앞)
# 1  2025  1  1     0   1044   20대     1  1314.19              굽은다리역
# 2  2025  1  1     0   1153   20대     1   992.04  발산역 1번, 9번 인근 대여소
# 3  2025  1  1     0   1260   20대     1  3187.35      방이동 한양3차아파트 옆
# 4  2025  1  1     0   1845   20대     1  2090.00      롯데캐슬골드파크1차 서문
# 5  2025  1  1     0   1338   20대     1  2840.00             용문2교 옆
# 6  2025  1  1     0   1725   20대     1   700.00            창1동주민센터
# 7  2025  1  1     0   1452   20대     1  1436.47            겸재교 진입부
# 8  2025  1  1     0   1278   20대     1  2273.58           송파구청 교차로
# 9  2025  1  1     0   1543   20대     1  1370.00          수유1동 주민센터

# %%
df7 = pd.read_csv('data/time/서울특별시 공공자전거 이용정보(시간대별)_202507.csv')
df7.head()
# Out:
#          대여일자  대여시간  대여소번호                 대여소명 대여구분코드   성별 연령대코드  이용건수  \
# 0  2025-07-01     0   1293    1293. 석촌호수 서호 사거리    정기권  NaN  ~10대     1
# 1  2025-07-01     0    739           739. 신월사거리    정기권  NaN   20대     1
# 2  2025-07-01     0    505  505. 자양사거리 광진아크로텔 앞    정기권  NaN   20대     2
# 3  2025-07-01     0   1529     1529. 미아동 한국전력공사    정기권  NaN   20대     1
# 4  2025-07-01     0   1650        1650. 중계근린공원내    정기권  NaN   20대     2
#
#      운동량   탄소량  이동거리(M)  이용시간(분)
# 0  15.83  0.14   615.10        5
# 1   9.81  0.09   381.15        4
# 2  31.36  0.33  1393.80        8
# 3  79.58  0.72  3091.62       16
# 4  76.78  0.69  2982.88       38

# %%
for month in range(7, 13):
    
    # 파일 경로
    file = f'data/time/서울특별시 공공자전거 이용정보(시간대별)_2025{month:02d}.csv'
    
    # CSV 불러오기
    df1 = pd.read_csv(file)

    # 대여소번호와 대여소 분리
    df1[['대여소번호', '대여소']] = df1['대여소명'].str.extract(
        r'^(\d+)\.\s*(.*)$'
    )

    # 대여소번호 숫자 변환
    df1['대여소번호'] = pd.to_numeric(
        df['대여소번호'],
        errors='coerce'
    )

    # 대여소 이름 공백 제거
    df1['대여소'] = df1['대여소'].str.strip()

    # 날짜 변환
    df1['대여일자'] = pd.to_datetime(
        df1['대여일자'],
        errors='coerce'
    )

    # 연도 / 월 / 일 분리
    df1['연도'] = df1['대여일자'].dt.year
    df1['월'] = df1['대여일자'].dt.month
    df1['일'] = df1['대여일자'].dt.day

    # 원하는 컬럼 순서
    cols = ['연도', '월', '일'] + [
        col for col in df1.columns
        if col not in ['연도', '월', '일']
    ]

    df1 = df1[cols]

    # 불필요한 컬럼 삭제
    df1 = df1.drop(
        ['대여소명', '대여일자', '대여구분코드', '성별', '운동량', '탄소량', '이용시간(분)'],
        axis=1
    )

    # 대여소번호 정수형 변환
    df1['대여소번호'] = df1['대여소번호'].astype('Int64')

    # 대여소번호 결측치 제거
    df1 = df1.dropna(subset=['대여소번호'])

    # # 대여소별 이용건수 합계
    # df = (
    #     df.groupby(
    #         ['연도', '월', '대여소번호', '대여소'],
    #         as_index=False
    #     )['이용건수']
    #     .sum()
    #     .reset_index(drop=True)
    # )

    # df_202501, df_202502 ... 형태로 저장
    globals()[f'df_2025{month:02d}'] = df1

# %%
for month in range(1, 13):
    df = globals()[f'df_2025{month:02d}']
    
    df.to_csv(
        f'data/월별_대여소별_공공자전거_이용건수_2025{month:02d}.csv',
        index=False,
        encoding='utf-8-sig'
    )

print('데이터 저장 완료!')
# Out:
# 데이터 저장 완료!

# %%
globals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   'import pandas as pd',
#   "df1 = pd.read_csv('data/time/서울특별시 공공자전거 이용정보(시간대별)_202501.csv')\ndf1.head()",
#   '# 2025년 1월 데이터 전처리',
#   '# 2025년 1월 데이터 정제',
#   "df1[['대여소번호', '대여소']] = df1['대여소명'].str.extract(\n    r'^(\\d+)\\.\\s*(.*)$'\n)\n\ndf1['대여소번호'] = pd.to_numeric(\n    df1['대여소번호'],\n    errors='coerce'\n)\n\ndf1['대여소'] = df1['대여소'].str.strip()\ndf1 = df1.drop(['대여소명', '대여구분코드', '성별', '운동량', '탄소량'], axis=1)",
#   'df1.head()',
#   'df1.info()',
#   "df1['대여일자'] = pd.to_datetime(df1['대여일자'], errors='coerce')\n\ndf1['연도'] = df1['대여일자'].dt.year\ndf1['월'] = df1['대여일자'].dt.month\ndf1['일'] = df1['대여일자'].dt.day\n\ndf1.head()",
#   "df1 = pd.read_csv('data/time/서울특별시 공공자전거 이용정보(시간대별)_202501.csv')\ndf1.head()",
#   'df1.info()',
#   "df1[['대여소번호', '대여소']] = df1['대여소명'].str.extract(\n    r'^(\\d+)\\.\\s*(.*)$'\n)\n\ndf1['대여소번호'] = pd.to_numeric(\n    df1['대여소번호'],\n    errors='coerce'\n)\n\ndf1['대여소'] = df1['대여소'].str.strip()",
#   'df1.head()',
#   "df1['대여일자'] = pd.to_datetime(df1['대여일자'], errors='coerce')\n\ndf1['연도'] = df1['대여일자'].dt.year\ndf1['월'] = df1['대여일자'].dt.month\ndf1['일'] = df1['대여일자'].dt.day\n\n# 원하는 컬럼 순서 지정\ncols = ['연도', '월', '일'] + [col for col in df.columns if col not in ['연도', '월', '일']]\n\ndf1 = df1[cols]\ndf1 = df1.drop(['대여소명', '대여구분코드', '성별', '운동량', '탄소량'], axis=1)\ndf1.head()",
#   "df1['대여일자'] = pd.to_datetime(df1['대여일자'], errors='coerce')\n\ndf1['연도'] = df1['대여일자'].dt.year\ndf1['월'] = df1['대여일자'].dt.month\ndf1['일'] = df1['대여일자'].dt.day\n\n# 원하는 컬럼 순서 지정\ncols = ['연도', '월', '일'] + [col for col in df1.columns if col not in ['연도', '월', '일']]\n\ndf1 = df1[cols]\ndf1 = df1.drop(['대여소명', '대여구분코드', '성별', '운동량', '탄소량'], axis=1)\ndf1.head()",
#   "df1 = pd.read_csv('data/time/서울특별시 공공자전거 이용정보(시간대별)_202501.csv')\ndf1.head()",
#   "df1[['대여소번호', '대여소']] = df1['대여소명'].str.extract(\n    r'^(\\d+)\\.\\s*(.*)$'\n)\n\ndf1['대여소번호'] = pd.to_numeric(\n    df1['대여소번호'],\n    errors='coerce'\n)\n\ndf1['대여소'] = df1['대여소'].str.strip()",
#   'df1.head()',
#   "df1['대여일자'] = pd.to_datetime(df1['대여일자'], errors='coerce')\n\ndf1['연도'] = df1['대여일자'].dt.year\ndf1['월'] = df1['대여일자'].dt.month\ndf1['일'] = df1['대여일자'].dt.day\n\n# 원하는 컬럼 순서 지정\ncols = ['연도', '월', '일'] + [col for col in df1.columns if col not in ['연도', '월', '일']]\n\ndf1 = df1[cols]\ndf1 = df1.drop(['대여소명', '대여일자', '대여구분코드', '성별', '운동량', '탄소량'], axis=1)\ndf1.head()",
#   "df1['대여소번호'] = df1['대여소번호'].astype('Int64')\ndf1.head()",
#   'df1.isna().sum()',
#   "df1 = df_date_re.dropna(subset='대여소번호')",
#   "df1 = df1.dropna(subset='대여소번호')\ndf1.isna().sum()",
#   "df1 = pd.read_csv('data/time/서울특별시 공공자전거 이용정보(시간대별)_202501.csv')\ndf1.head()",
#   'df1.info()',
#   'df1.isna().sum()',
#   "df1[['대여소번호', '대여소']] = df1['대여소명'].str.extract(\n    r'^(\\d+)\\.\\s*(.*)$'\n)\n\ndf1['대여소번호'] = pd.to_numeric(\n    df1['대여소번호'],\n    errors='coerce'\n)\n\ndf1['대여소'] = df1['대여소'].str.strip()",
#   'df1.head()',
#   'df1.isna().sum()',
#   "df1 = pd.read_csv('data/time/서울특별시 공공자전거 이용정보(시간대별)_202501.csv')\ndf1.head()",
#   'df1.isna().sum()',
#   "df1[df1['대여소명'].str.extract(r'^(\\d+)')[0].isna()]['대여소명'].unique()",
#   "# 1. 대여소명에서 '숫자.' 형태인 경우 번호 추출\nextracted_number = pd.to_numeric(\n    df1['대여소명'].str.extract(r'^(\\d+)\\.')[0],\n    errors='coerce'\n)\n\n# 2. 기존 대여소번호를 우선 사용\n# 기존 값이 NaN인 경우에만 extracted_number 사용\ndf1['대여소번호'] = df1['대여소번호'].fillna(extracted_number)\n\n# 3. '숫자.'가 존재하는 경우에만 '.' 뒤를 대여소명으로 사용\nmask = df1['대여소명'].str.match(r'^\\d+\\.', na=False)\n\ndf1.loc[mask, '대여소'] = (\n    df1.loc[mask, '대여소명']\n    .str.split('.', n=1)\n    .str[1]\n    .str.strip()\n)\n\n# 4. 숫자로 시작하지 않는 경우에는 기존 대여소명을 그대로 사용\ndf1.loc[~mask, '대여소'] = df1.loc[~mask, '대여소명'].str.strip()",
#   'df1.head()',
#   'df1.isna().sum()',
#   "df1[df1['대여소명'].str.extract(r'^(\\d+)')[0].isna()]['대여소명'].unique()",
#   "print(df1['대여소명'] == 'AS센터')",
#   "df1 = pd.read_csv('data/time/서울특별시 공공자전거 이용정보(시간대별)_202501.csv')\ndf1.head()",
#   'df1.isna().sum()',
#   "df1[df1['대여소명'].str.extract(r'^(\\d+)')[0].isna()]['대여소명'].unique()",
#   "# 대여소명에서 숫자로 시작하는 경우에만 번호 추출\nextracted_number = pd.to_numeric(\n    df1['대여소명'].str.extract(r'^(\\d+)\\.')[0],\n    errors='coerce'\n)\n\n# 기존 대여소번호가 없는 경우에만 추출한 번호로 채우기\ndf1['대여소번호'] = df1['대여소번호'].fillna(extracted_number)\n\n# 대여소명에서 첫 번째 '.' 뒤의 대여소 이름 추출\ndf1['대여소'] = df1['대여소명'].str.split('.', n=1).str[-1].str.strip()",
#   'df1.head()',
#   'df1.isna().sum()',
#   "df1[df1['대여소명'].str.extract(r'^(\\d+)')[0].isna()]['대여소명'].unique()",
#   'df1.head()',
#   "df1 = pd.read_csv('data/time/서울특별시 공공자전거 이용정보(시간대별)_202501.csv')\ndf1.head()",
#   'df1.isna().sum()',
#   "df1[df1['대여소명'].str.extract(r'^(\\d+)')[0].isna()]['대여소명'].unique()",
#   "# 대여소명에서 '숫자.' 패턴 추출\nextracted = df1['대여소명'].str.extract(r'^(\\d+)\\.\\s*(.*)$')\n\n# 숫자로 시작하는 경우\nmask = extracted[0].notna()\n\n# 대여소번호 덮어쓰기\ndf1.loc[mask, '대여소번호'] = pd.to_numeric(\n    extracted.loc[mask, 0],\n    errors='coerce'\n)\n\n# 대여소명에서 숫자. 부분을 제거하고 대여소만 저장\ndf1.loc[mask, '대여소'] = extracted.loc[mask, 1].str.strip()\n\n# 숫자로 시작하지 않는 경우\n# 기존 대여소번호는 그대로 유지\n# 대여소는 기존 DB 형식처럼 대여소명 자체를 사용\ndf1.loc[~mask, '대여소'] = df1.loc[~mask, '대여소명'].str.strip()",
#   'df1.head()',
#   'df1.isna().sum()',
#   "df1[df1['대여소명'].str.extract(r'^(\\d+)')[0].isna()]['대여소명'].unique()",
#   "df_date_re[['대여소번호', '대여소']] = df_date_re['대여소'].str.extract(\n    r'^(\\d+)\\.\\s*(.*)$'\n)\n\ndf_date_re['대여소번호'] = pd.to_numeric(\n    df_date_re['대여소번호'],\n    errors='coerce'\n)\n\ndf_date_re['대여소'] = df_date_re['대여소'].str.strip()\n\ndf_date_re.head()",
#   "df1[['대여소번호', '대여소']] = df1['대여소'].str.extract(\n    r'^(\\d+)\\.\\s*(.*)$'\n)\n\ndf1['대여소번호'] = pd.to_numeric(\n    df1['대여소번호'],\n    errors='coerce'\n)\n\ndf1['대여소'] = df1['대여소'].str.strip()",
#   'df1.head()',
#   "df1 = pd.read_csv('data/time/서울특별시 공공자전거 이용정보(시간대별)_202501.csv')\ndf1.head()",
#   'df1.isna().sum()',
#   "df1[df1['대여소명'].str.extract(r'^(\\d+)')[0].isna()]['대여소명'].unique()",
#   "df1[['대여소번호', '대여소']] = df1['대여소'].str.extract(\n    r'^(\\d+)\\.\\s*(.*)$'\n)\n\ndf1['대여소번호'] = pd.to_numeric(\n    df1['대여소번호'],\n    errors='coerce'\n)\n\ndf1['대여소'] = df1['대여소'].str.strip()",
#   "df1[['대여소번호', '대여소']] = df1['대여소명'].str.extract(\n    r'^(\\d+)\\.\\s*(.*)$'\n)\n\ndf1['대여소번호'] = pd.to_numeric(\n    df1['대여소번호'],\n    errors='coerce'\n)\n\ndf1['대여소'] = df1['대여소'].str.strip()",
#   'df1.head()',
#   'df1.isna().sum()',
#   'df1.isna().sum()',
#   "df1['대여일자'] = pd.to_datetime(df1['대여일자'], errors='coerce')\n\ndf1['연도'] = df1['대여일자'].dt.year\ndf1['월'] = df1['대여일자'].dt.month\ndf1['일'] = df1['대여일자'].dt.day\n\n# 원하는 컬럼 순서 지정\ncols = ['연도', '월', '일'] + [col for col in df1.columns if col not in ['연도', '월', '일']]\n\ndf1 = df1[cols]\ndf1 = df1.drop(['대여소명', '대여일자', '대여구분코드', '성별', '운동량', '탄소량'], axis=1)\ndf1.head()",
#   "df1['대여소번호'] = df1['대여소번호'].astype('Int64')\ndf1.head()",
#   "df1 = df1.dropna(subset='대여소번호')\ndf1.isna().sum()",
#   'df1.head()',
#   'df1.head()',
#   "df1.groupby(['연도', '월', '일', '대여시간'])['이용건수'].sum()",
#   "df1.groupby(['연도', '월', '일', '대여시간', '대여소번호', '대여소'], as_index=False)['이용건수'].sum()",
#   "df1.groupby(['연도', '월', '일', '대여시간', '대여소번호', '대여소'], as_index=False)['이용건수'].sum().head()",
#   "df1.groupby('연령대코드', as_index=False)['이용건수'].sum()",
#   "df1.groupby(['연도', '월', '일', '대여시간', '대여소번호', '대여소'], as_index=False)['이용건수'].sum().sort_values('이용건수', ascending=False).reset_index(drop=False)",
#   "df1_top = df1.groupby(['연도', '월', '일', '대여시간', '대여소번호', '대여소'], as_index=False)['이용건수'].sum().sort_values('이용건수', ascending=False).reset_index(drop=False)\ndf1_top.head(6)",
#   "df1_top = df1.groupby(['연도', '월', '일', '대여시간', '대여소번호', '대여소'], as_index=False)['이용건수'].sum().sort_values('이용건수', ascending=False).reset_index(drop=False)\ndf1_top.head()",
#   "df1_top = df1.groupby(['연도', '월', '일', '대여시간', '대여소번호', '대여소'], as_index=False)['이용건수'].sum()\ndf1_top.head()",
#   "df1_top = df1.groupby(['연도', '월', '대여시간', '대여소번호', '대여소'], as_index=False)['이용건수'].sum().sort_values('이용건수', ascending=False).reset_index(drop=False)\ndf1_top.head()",
#   "df1_top = df1.groupby(['연도', '월', '대여소번호', 대여소'], as_index=False)['이용건수'].sum().sort_values('이용건수', ascending=False).reset_index(drop=False)\ndf1_top.head()",
#   "df1_top = df1.groupby(['연도', '월', '대여소번호', '대여소'], as_index=False)['이용건수'].sum().sort_values('이용건수', ascending=False).reset_index(drop=False)\ndf1_top.head()",
#   "df1_top = df1.groupby(['연도', '월', '대여소번호', '대여소'], as_index=False)['이용건수'].sum().sort_values('이용건수', ascending=False).reset_index(drop=False)\ndf1_top",
#   "df1_top = df1.groupby(['연도', '월', '대여소번호', '대여소'], as_index=False)['이용건수'].sum().sort_values('이용건수', ascending=False).reset_index(drop=False)\ndf1_top.head(6)",
#   "df1_top = df1.groupby(['연도', '월', '대여소번호', '대여소'], as_index=False)['이용건수'].sum().sort_values('이용건수', ascending=False).reset_index(drop=False)\ndf1_top",
#   "df1_top = df1.groupby(['연도', '월', '대여소번호', '대여소'], as_index=False)['이용건수'].sum().sort_values('이용건수', ascending=False).reset_index()\ndf1_top",
#   "df1_top = df1.groupby(['연도', '월', '대여소번호', '대여소'], as_index=False)['이용건수'].sum().sort_values('이용건수', ascending=False)\ndf1_top",
#   "df1_top = df1.groupby(['연도', '월', '대여소번호', '대여소'], as_index=False)['이용건수'].sum().sort_values('이용건수', ascending=False).reset_index(drop=True)\ndf1_top",
#   "df1.groupby('연령대코드', as_index=False)['이용건수'].sum().sort_values('이용건수', ascending=False)",
#   'df1_top.shape',
#   "df2 = pd.read_csv('data/time/서울특별시 공공자전거 이용정보(시간대별)_202502.csv')\ndf2.head()",
#   'df2.info()',
#   'df2.isna().sum()',
#   "df2[df2['대여소명'].str.extract(r'^(\\d+)')[0].isna()]['대여소명'].unique()",
#   'import pandas as pd\n\ndf_list = []\n\nfor month in range(1, 13):\n    file = f"data/time/서울특별시 공공자전거 이용정보(시간대별)_2025{month:02d}.csv"\n\n    df = pd.read_csv(file)\n\n    # 대여소번호, 대여소 분리\n    df[[\'대여소번호\', \'대여소\']] = df[\'대여소명\'].str.extract(\n        r\'^(\\d+)\\.\\s*(.*)$\'\n    )\n\n    df[\'대여소번호\'] = pd.to_numeric(df[\'대여소번호\'], errors=\'coerce\')\n    df[\'대여소\'] = df[\'대여소\'].str.strip()\n\n    # 날짜 처리\n    df[\'대여일자\'] = pd.to_datetime(df[\'대여일자\'], errors=\'coerce\')\n    df[\'연도\'] = df[\'대여일자\'].dt.year\n    df[\'월\'] = df[\'대여일자\'].dt.month\n    df[\'일\'] = df[\'대여일자\'].dt.day\n\n    # 컬럼 순서 변경\n    cols = [\'연도\', \'월\', \'일\'] + [\n        col for col in df.columns if col not in [\'연도\', \'월\', \'일\']\n    ]\n    df = df[cols]\n\n    # 불필요한 컬럼 삭제\n    df = df.drop(\n        [\'대여소명\', \'대여일자\', \'대여구분코드\', \'성별\', \'운동량\', \'탄소량\'],\n        axis=1\n    )\n\n    df[\'대여소번호\'] = df[\'대여소번호\'].astype(\'Int64\')\n    df = df.dropna(subset=[\'대여소번호\'])\n\n    df_list.append(df)\n\n# 모든 월 합치기\ndf_all = pd.concat(df_list, ignore_index=True)\n\n# 월별 이용건수 합계\ndf_top = (\n    df_all.groupby([\'연도\', \'월\', \'대여소번호\', \'대여소\'], as_index=False)[\'이용건수\']\n    .sum()\n    .sort_values(\'이용건수\', ascending=False)\n    .reset_index(drop=True)\n)\n\ndf_top',
#   'import pandas as pd\n\ndf_list = []\n\nfor month in range(1, 13):\n    file = f"data/time/서울특별시 공공자전거 이용정보(시간대별)_2025{month:02d}.csv"\n\n    df = pd.read_csv(file)\n\n    # 대여소번호, 대여소 분리\n    df[[\'대여소번호\', \'대여소\']] = df[\'대여소명\'].str.extract(\n        r\'^(\\d+)\\.\\s*(.*)$\'\n    )\n\n    df[\'대여소번호\'] = pd.to_numeric(df[\'대여소번호\'], errors=\'coerce\')\n    df[\'대여소\'] = df[\'대여소\'].str.strip()\n\n    # 날짜 처리\n    df[\'대여일자\'] = pd.to_datetime(df[\'대여일자\'], errors=\'coerce\')\n    df[\'연도\'] = df[\'대여일자\'].dt.year\n    df[\'월\'] = df[\'대여일자\'].dt.month\n    df[\'일\'] = df[\'대여일자\'].dt.day\n\n    # 컬럼 순서 변경\n    cols = [\'연도\', \'월\', \'일\'] + [\n        col for col in df.columns if col not in [\'연도\', \'월\', \'일\']\n    ]\n    df = df[cols]\n\n    # 불필요한 컬럼 삭제\n    df = df.drop(\n        [\'대여소명\', \'대여일자\', \'대여구분코드\', \'성별\', \'운동량\', \'탄소량\'],\n        axis=1\n    )\n\n    df[\'대여소번호\'] = df[\'대여소번호\'].astype(\'Int64\')\n    df = df.dropna(subset=[\'대여소번호\'])\n\n    df_list.append(df)\n\n# 모든 월 합치기\ndf_all = pd.concat(df_list, ignore_index=True)\n\n# 월별 이용건수 합계\ndf_top = (\n    df_all.groupby([\'연도\', \'월\', \'대여소번호\', \'대여소\'], as_index=False)[\'이용건수\']\n    .sum()\n    .sort_values(\'이용건수\', ascending=False)\n    .reset_index(drop=True)\n)\n\ndf_top.head()',
#   'df_top',
#   'df_top.shape',
#   'df_top.info()',
#   'df_top.isna().sum()',
#   'import pandas as pd\n\ndf_list = []\n\nfor month in range(1, 13):\n    file = f"data/time/서울특별시 공공자전거 이용정보(시간대별)_2025{month:02d}.csv"\n\n    df = pd.read_csv(file)\n\n    # 대여소번호, 대여소 분리\n    df[[\'대여소번호\', \'대여소\']] = df[\'대여소명\'].str.extract(\n        r\'^(\\d+)\\.\\s*(.*)$\'\n    )\n\n    df[\'대여소번호\'] = pd.to_numeric(df[\'대여소번호\'], errors=\'coerce\')\n    df[\'대여소\'] = df[\'대여소\'].str.strip()\n\n    # 날짜 처리\n    df[\'대여일자\'] = pd.to_datetime(df[\'대여일자\'], errors=\'coerce\')\n    df[\'연도\'] = df[\'대여일자\'].dt.year\n    df[\'월\'] = df[\'대여일자\'].dt.month\n    df[\'일\'] = df[\'대여일자\'].dt.day\n\n    # 컬럼 순서 변경\n    cols = [\'연도\', \'월\', \'일\'] + [\n        col for col in df.columns if col not in [\'연도\', \'월\', \'일\']\n    ]\n    df = df[cols]\n\n    # 불필요한 컬럼 삭제\n    df = df.drop(\n        [\'대여소명\', \'대여일자\', \'대여구분코드\', \'성별\', \'운동량\', \'탄소량\'],\n        axis=1\n    )\n\n    df[\'대여소번호\'] = df[\'대여소번호\'].astype(\'Int64\')\n    df = df.dropna(subset=[\'대여소번호\'])\n\n    df_list.append(df)\n\n# 모든 월 합치기\ndf_all = pd.concat(df_list, ignore_index=True)\n\n# 월별 이용건수 합계\ndf_top = (\n    df_all.groupby([\'연도\', \'월\', \'대여소번호\', \'대여소\'], as_index=False)[\'이용건수\']\n    .sum()\n    .sort_values(\'이용건수\', ascending=False)\n    .reset_index(drop=True)\n)\n\ndf_top',
#   'import pandas as pd\n\ndf_list = []\n\nfor month in range(1, 13):\n    file = f"data/time/서울특별시 공공자전거 이용정보(시간대별)_2025{month:02d}.csv"\n\n    df = pd.read_csv(file)\n\n    # 대여소번호, 대여소 분리\n    df[[\'대여소번호\', \'대여소\']] = df[\'대여소명\'].str.extract(\n        r\'^(\\d+)\\.\\s*(.*)$\'\n    )\n\n    df[\'대여소번호\'] = pd.to_numeric(df[\'대여소번호\'], errors=\'coerce\')\n    df[\'대여소\'] = df[\'대여소\'].str.strip()\n\n    # 날짜 처리\n    df[\'대여일자\'] = pd.to_datetime(df[\'대여일자\'], errors=\'coerce\')\n    df[\'연도\'] = df[\'대여일자\'].dt.year\n    df[\'월\'] = df[\'대여일자\'].dt.month\n    df[\'일\'] = df[\'대여일자\'].dt.day\n\n    # 컬럼 순서 변경\n    cols = [\'연도\', \'월\', \'일\'] + [\n        col for col in df.columns if col not in [\'연도\', \'월\', \'일\']\n    ]\n    df = df[cols]\n\n    # 불필요한 컬럼 삭제\n    df = df.drop(\n        [\'대여소명\', \'대여일자\', \'대여구분코드\', \'성별\', \'운동량\', \'탄소량\'],\n        axis=1\n    )\n\n    df[\'대여소번호\'] = df[\'대여소번호\'].astype(\'Int64\')\n    df = df.dropna(subset=[\'대여소번호\'])\n\n    df_list.append(df)\n\n# 모든 월 합치기\ndf_all = pd.concat(df_list, ignore_index=True)\n\n# 월별 이용건수 합계\ndf_top = (\n    df_all.groupby([\'연도\', \'월\', \'대여소번호\', \'대여소\'], as_index=False)[\'이용건수\']\n    .sum()\n    .reset_index(drop=True)\n)\n\ndf_top',
#   "for month in range(1, 13):\n\n    # 파일 경로\n    file = f'data/time/서울특별시 공공자전거 이용정보(시간대별)_2025{month:02d}.csv'\n\n    # CSV 불러오기\n    df = pd.read_csv(file)\n\n    # 대여소번호와 대여소 분리\n    df[['대여소번호', '대여소']] = df['대여소명'].str.extract(\n        r'^(\\d+)\\.\\s*(.*)$'\n    )\n\n    # 대여소번호 숫자 변환\n    df['대여소번호'] = pd.to_numeric(\n        df['대여소번호'],\n        errors='coerce'\n    )\n\n    # 대여소 이름 공백 제거\n    df['대여소'] = df['대여소'].str.strip()\n\n    # 날짜 변환\n    df['대여일자'] = pd.to_datetime(\n        df['대여일자'],\n        errors='coerce'\n    )\n\n    # 연도 / 월 / 일 분리\n    df['연도'] = df['대여일자'].dt.year\n    df['월'] = df['대여일자'].dt.month\n    df['일'] = df['대여일자'].dt.day\n\n    # 원하는 컬럼 순서\n    cols = ['연도', '월', '일'] + [\n        col for col in df.columns\n        if col not in ['연도', '월', '일']\n    ]\n\n    df = df[cols]\n\n    # 불필요한 컬럼 삭제\n    df = df.drop(\n        ['대여소명', '대여일자', '대여구분코드', '성별', '운동량', '탄소량'],\n        axis=1\n    )\n\n    # 대여소번호 정수형 변환\n    df['대여소번호'] = df['대여소번호'].astype('Int64')\n\n    # 대여소번호 결측치 제거\n    df = df.dropna(subset=['대여소번호'])\n\n    # 대여소별 이용건수 합계\n    df = (\n        df.groupby(\n            ['연도', '월', '대여소번호', '대여소'],\n            as_index=False\n        )['이용건수']\n        .sum()\n        .reset_index(drop=True)\n    )\n\n    # df_202501, df_202502 ... 형태로 저장\n    globals()[f'df_2025{month:02d}'] = df",
#   'df_202501.head()',
#   "df_top.to_csv('data/월별_대여소별_공공자전거_이용건수_전체.csv', index=False, encoding='utf-8-sig')\n\nprint('데이터 저장 완료!')",
#   "for month in range(1, 13):\n    df = globals()[f'df_2025{month:02d}']\n\n    df.to_csv(\n        f'data/월별_대여소별_공공자전거_이용건수_2025{month:02d}.csv',\n        index=False,\n        encoding='utf-8-sig'\n    )\n\nprint('데이터 저장 완료!')",
#   'df_202501.head(10)',
#   "df2 = pd.read_csv('data/time/서울특별시 공공자전거 이용정보(시간대별)_202502.csv')\ndf2.head()",
#   "df2[['대여소번호', '대여소']] = df2['대여소명'].str.extract(\n    r'^(\\d+)\\.\\s*(.*)$'\n)\n\ndf2['대여소번호'] = pd.to_numeric(\n    df2['대여소번호'],\n    errors='coerce'\n)\n\ndf2['대여소'] = df2['대여소'].str.strip()\n\ndf2['대여일자'] = pd.to_datetime(df2['대여일자'], errors='coerce')\n\ndf2['연도'] = df2['대여일자'].dt.year\ndf2['월'] = df2['대여일자'].dt.month\ndf2['일'] = df2['대여일자'].dt.day\n\n# 원하는 컬럼 순서 지정\ncols = ['연도', '월', '일'] + [col for col in df2.columns if col not in ['연도', '월', '일']]\n\ndf2 = df2[cols]\ndf2 = df2.drop(['대여소명', '대여일자', '대여구분코드', '성별', '운동량', '탄소량'], axis=1)\ndf2['대여소번호'] = df2['대여소번호'].astype('Int64')\ndf2 = df2.dropna(subset='대여소번호')",
#   "df2_top = df2.groupby(['연도', '월', '대여소번호', '대여소', '연령대코드', '이동거리'], as_index=False)['이용건수'].sum().sort_values('이용건수', ascending=False).reset_index(drop=True)\ndf2_top",
#   'df2.head(15)',
#   'import pandas as pd\n\ndf_list = []\n\nfor month in range(1, 13):\n    file = f"data/time/서울특별시 공공자전거 이용정보(시간대별)_2025{month:02d}.csv"\n\n    df = pd.read_csv(file)\n\n    # 대여소번호, 대여소 분리\n    df[[\'대여소번호\', \'대여소\']] = df[\'대여소명\'].str.extract(\n        r\'^(\\d+)\\.\\s*(.*)$\'\n    )\n\n    df[\'대여소번호\'] = pd.to_numeric(df[\'대여소번호\'], errors=\'coerce\')\n    df[\'대여소\'] = df[\'대여소\'].str.strip()\n\n    # 날짜 처리\n    df[\'대여일자\'] = pd.to_datetime(df[\'대여일자\'], errors=\'coerce\')\n    df[\'연도\'] = df[\'대여일자\'].dt.year\n    df[\'월\'] = df[\'대여일자\'].dt.month\n    df[\'일\'] = df[\'대여일자\'].dt.day\n\n    # 컬럼 순서 변경\n    cols = [\'연도\', \'월\', \'일\'] + [\n        col for col in df.columns if col not in [\'연도\', \'월\', \'일\']\n    ]\n    df = df[cols]\n\n    # 불필요한 컬럼 삭제\n    df = df.drop(\n        [\'대여소명\', \'대여일자\', \'대여구분코드\', \'성별\', \'운동량\', \'탄소량\'],\n        axis=1\n    )\n\n    df[\'대여소번호\'] = df[\'대여소번호\'].astype(\'Int64\')\n    df = df.dropna(subset=[\'대여소번호\'])\n\n    df_list.append(df)\n\n# 모든 월 합치기\ndf_all = pd.concat(df_list, ignore_index=True)\n\n# 월별 이용건수 합계\n# df_top = (\n#     df_all.groupby([\'연도\', \'월\', \'대여소번호\', \'대여소\', \'연령대코드\', \'이동거리\'], as_index=False)[\'이용건수\']\n#     .sum()\n#     .reset_index(drop=True)\n# )\n\ndf_all.head(20)',
#   'import pandas as pd',
#   "df1 = pd.read_csv('data/서울특별시 공공자전거 이용정보(시간대별)_202501.csv')\ndf1.head()",
#   "df1 = pd.read_csv('data/time/서울특별시 공공자전거 이용정보(시간대별)_202501.csv')\ndf1.head()",
#   'import pandas as pd\n\ndf_list = []\n\nfor month in range(1, 13):\n    file = f"data/time/서울특별시 공공자전거 이용정보(시간대별)_2025{month:02d}.csv"\n\n    df = pd.read_csv(file)\n\n    # 대여소번호, 대여소 분리\n    df[[\'대여소번호\', \'대여소\']] = df[\'대여소명\'].str.extract(\n        r\'^(\\d+)\\.\\s*(.*)$\'\n    )\n\n    df[\'대여소번호\'] = pd.to_numeric(df[\'대여소번호\'], errors=\'coerce\')\n    df[\'대여소\'] = df[\'대여소\'].str.strip()\n\n    # 날짜 처리\n    df[\'대여일자\'] = pd.to_datetime(df[\'대여일자\'], errors=\'coerce\')\n    df[\'연도\'] = df[\'대여일자\'].dt.year\n    df[\'월\'] = df[\'대여일자\'].dt.month\n    df[\'일\'] = df[\'대여일자\'].dt.day\n\n    # 컬럼 순서 변경\n    cols = [\'연도\', \'월\', \'일\'] + [\n        col for col in df.columns if col not in [\'연도\', \'월\', \'일\']\n    ]\n    df = df[cols]\n\n    # 불필요한 컬럼 삭제\n    df = df.drop(\n        [\'대여소명\', \'대여일자\', \'대여구분코드\', \'성별\', \'운동량\', \'탄소량\'],\n        axis=1\n    )\n\n    df[\'대여소번호\'] = df[\'대여소번호\'].astype(\'Int64\')\n    df = df.dropna(subset=[\'대여소번호\'])\n\n    df_list.append(df)\n\n# 모든 월 합치기\ndf_all = pd.concat(df_list, ignore_index=True)\n\n# 월별 이용건수 합계\n# df_top = (\n#     df_all.groupby([\'연도\', \'월\', \'대여소번호\', \'대여소\', \'연령대코드\', \'이동거리\'], as_index=False)[\'이용건수\']\n#     .sum()\n#     .reset_index(drop=True)\n# )\n\ndf_all.head(20)',
#   "df1 = pd.read_csv('data/time/서울특별시 공공자전거 이용정보(시간대별)_202502.csv')\ndf1.head()",
#   "df1 = pd.read_csv('data/time/서울특별시 공공자전거 이용정보(시간대별)_202503.csv')\ndf1.head()",
#   "df1 = pd.read_csv('data/time/서울특별시 공공자전거 이용정보(시간대별)_202504.csv')\ndf1.head()",
#   "df1 = pd.read_csv('data/time/서울특별시 공공자전거 이용정보(시간대별)_202505.csv')\ndf1.head()",
#   "df1 = pd.read_csv('data/time/서울특별시 공공자전거 이용정보(시간대별)_202506.csv')\ndf1.head()",
#   "df1 = pd.read_csv('data/time/서울특별시 공공자전거 이용정보(시간대별)_202507.csv')\ndf1.head()",
#   'import pandas as pd\n\ndf_list = []\n\nfor month in range(1, 7):\n    file = f"data/time/서울특별시 공공자전거 이용정보(시간대별)_2025{month:02d}.csv"\n\n    df = pd.read_csv(file)\n\n    # 대여소번호, 대여소 분리\n    df[[\'대여소번호\', \'대여소\']] = df[\'대여소명\'].str.extract(\n        r\'^(\\d+)\\.\\s*(.*)$\'\n    )\n\n    df[\'대여소번호\'] = pd.to_numeric(df[\'대여소번호\'], errors=\'coerce\')\n    df[\'대여소\'] = df[\'대여소\'].str.strip()\n\n    # 날짜 처리\n    df[\'대여일자\'] = pd.to_datetime(df[\'대여일자\'], errors=\'coerce\')\n    df[\'연도\'] = df[\'대여일자\'].dt.year\n    df[\'월\'] = df[\'대여일자\'].dt.month\n    df[\'일\'] = df[\'대여일자\'].dt.day\n\n    # 컬럼 순서 변경\n    cols = [\'연도\', \'월\', \'일\'] + [\n        col for col in df.columns if col not in [\'연도\', \'월\', \'일\']\n    ]\n    df = df[cols]\n\n    # 불필요한 컬럼 삭제\n    df = df.drop(\n        [\'대여소명\', \'대여일자\', \'대여구분코드\', \'성별\', \'운동량\', \'탄소량\'],\n        axis=1\n    )\n\n    df[\'대여소번호\'] = df[\'대여소번호\'].astype(\'Int64\')\n    df = df.dropna(subset=[\'대여소번호\'])\n\n    df_list.append(df)\n\n# 모든 월 합치기\ndf_up = pd.concat(df_list, ignore_index=True)\n\n# 월별 이용건수 합계\n# df_top = (\n#     df_all.groupby([\'연도\', \'월\', \'대여소번호\', \'대여소\', \'연령대코드\', \'이동거리\'], as_index=False)[\'이용건수\']\n#     .sum()\n#     .reset_index(drop=True)\n# )\n\ndf_up.head(20)',
#   'import pandas as pd\n\ndf_list = []\n\nfor month in range(1, 7):\n    file = f"data/time/서울특별시 공공자전거 이용정보(시간대별)_2025{month:02d}.csv"\n\n    df = pd.read_csv(file)\n\n    # 대여소번호, 대여소 분리\n    df[[\'대여소번호\', \'대여소\']] = df[\'대여소명\'].str.extract(\n        r\'^(\\d+)\\.\\s*(.*)$\'\n    )\n\n    df[\'대여소번호\'] = pd.to_numeric(df[\'대여소번호\'], errors=\'coerce\')\n    df[\'대여소\'] = df[\'대여소\'].str.strip()\n\n    # 날짜 처리\n    df[\'대여일자\'] = pd.to_datetime(df[\'대여일자\'], errors=\'coerce\')\n    df[\'연도\'] = df[\'대여일자\'].dt.year\n    df[\'월\'] = df[\'대여일자\'].dt.month\n    df[\'일\'] = df[\'대여일자\'].dt.day\n\n    # 컬럼 순서 변경\n    cols = [\'연도\', \'월\', \'일\'] + [\n        col for col in df.columns if col not in [\'연도\', \'월\', \'일\']\n    ]\n    df = df[cols]\n\n    # 불필요한 컬럼 삭제\n    df = df.drop(\n        [\'대여소명\', \'대여일자\', \'대여구분코드\', \'성별\', \'운동량\', \'탄소량\'],\n        axis=1\n    )\n\n    df[\'대여소번호\'] = df[\'대여소번호\'].astype(\'Int64\')\n    df = df.dropna(subset=[\'대여소번호\'])\n\n    df_list.append(df)\n\n# 모든 월 합치기\ndf_up = pd.concat(df_list, ignore_index=True)\n\n# 월별 이용건수 합계\n# df_top = (\n#     df_all.groupby([\'연도\', \'월\', \'대여소번호\', \'대여소\', \'연령대코드\', \'이동거리\'], as_index=False)[\'이용건수\']\n#     .sum()\n#     .reset_index(drop=True)\n# )\n\ndf_up.head(20)',
#   'import pandas as pd',
#   "for month in range(1, 7):\n\n    # 파일 경로\n    file = f'data/time/서울특별시 공공자전거 이용정보(시간대별)_2025{month:02d}.csv'\n\n    # CSV 불러오기\n    df = pd.read_csv(file)\n\n    # 대여소번호와 대여소 분리\n    df[['대여소번호', '대여소']] = df['대여소명'].str.extract(\n        r'^(\\d+)\\.\\s*(.*)$'\n    )\n\n    # 대여소번호 숫자 변환\n    df['대여소번호'] = pd.to_numeric(\n        df['대여소번호'],\n        errors='coerce'\n    )\n\n    # 대여소 이름 공백 제거\n    df['대여소'] = df['대여소'].str.strip()\n\n    # 날짜 변환\n    df['대여일자'] = pd.to_datetime(\n        df['대여일자'],\n        errors='coerce'\n    )\n\n    # 연도 / 월 / 일 분리\n    df['연도'] = df['대여일자'].dt.year\n    df['월'] = df['대여일자'].dt.month\n    df['일'] = df['대여일자'].dt.day\n\n    # 원하는 컬럼 순서\n    cols = ['연도', '월', '일'] + [\n        col for col in df.columns\n        if col not in ['연도', '월', '일']\n    ]\n\n    df = df[cols]\n\n    # 불필요한 컬럼 삭제\n    df = df.drop(\n        ['대여소명', '대여일자', '대여구분코드', '성별', '운동량', '탄소량'],\n        axis=1\n    )\n\n    # 대여소번호 정수형 변환\n    df['대여소번호'] = df['대여소번호'].astype('Int64')\n\n    # 대여소번호 결측치 제거\n    df = df.dropna(subset=['대여소번호'])\n\n    # # 대여소별 이용건수 합계\n    # df = (\n    #     df.groupby(\n    #         ['연도', '월', '대여소번호', '대여소'],\n    #         as_index=False\n    #     )['이용건수']\n    #     .sum()\n    #     .reset_index(drop=True)\n    # )\n\n    # df_202501, df_202502 ... 형태로 저장\n    globals()[f'df_2025{month:02d}'] = df",
#   'df_202501.head(10)',
#   "df7 = pd.read_csv('/data/time/서울특별시 공공자전거 이용정보(시간대별)_202507.csv')\ndf7.head()",
#   "df7 = pd.read_csv('/data/time/서울특별시 공공자전거 이용정보(시간대별)_202507.csv')\ndf7.head()",
#   "df7 = pd.read_csv('data/time/서울특별시 공공자전거 이용정보(시간대별)_202507.csv')\ndf7.head()",
#   "for month in range(7, 13):\n\n    # 파일 경로\n    file = f'data/time/서울특별시 공공자전거 이용정보(시간대별)_2025{month:02d}.csv'\n\n    # CSV 불러오기\n    df1 = pd.read_csv(file)\n\n    # 대여소번호와 대여소 분리\n    df1[['대여소번호', '대여소']] = df1['대여소명'].str.extract(\n        r'^(\\d+)\\.\\s*(.*)$'\n    )\n\n    # 대여소번호 숫자 변환\n    df1['대여소번호'] = pd.to_numeric(\n        df['대여소번호'],\n        errors='coerce'\n    )\n\n    # 대여소 이름 공백 제거\n    df1['대여소'] = df1['대여소'].str.strip()\n\n    # 날짜 변환\n    df1['대여일자'] = pd.to_datetime(\n        df1['대여일자'],\n        errors='coerce'\n    )\n\n    # 연도 / 월 / 일 분리\n    df1['연도'] = df1['대여일자'].dt.year\n    df1['월'] = df1['대여일자'].dt.month\n    df1['일'] = df1['대여일자'].dt.day\n\n    # 원하는 컬럼 순서\n    cols = ['연도', '월', '일'] + [\n        col for col in df1.columns\n        if col not in ['연도', '월', '일']\n    ]\n\n    df1 = df1[cols]\n\n    # 불필요한 컬럼 삭제\n    df1 = df1.drop(\n        ['대여소명', '대여일자', '대여구분코드', '성별', '운동량', '탄소량', '이용시간(분)'],\n        axis=1\n    )\n\n    # 대여소번호 정수형 변환\n    df1['대여소번호'] = df1['대여소번호'].astype('Int64')\n\n    # 대여소번호 결측치 제거\n    df1 = df1.dropna(subset=['대여소번호'])\n\n    # # 대여소별 이용건수 합계\n    # df = (\n    #     df.groupby(\n    #         ['연도', '월', '대여소번호', '대여소'],\n    #         as_index=False\n    #     )['이용건수']\n    #     .sum()\n    #     .reset_index(drop=True)\n    # )\n\n    # df_202501, df_202502 ... 형태로 저장\n    globals()[f'df_2025{month:02d}'] = df1",
#   'globals()'],
#  '_oh': {2:          대여일자  대여시간  대여소번호                     대여소명 대여구분코드   성별 연령대코드  이용건수  \
#   0  2025-01-01     0   3684       3684. 고덕자이(105동 앞)    정기권  NaN  ~10대     1
#   1  2025-01-01     0   1044              1044. 굽은다리역    정기권  NaN   20대     1
#   2  2025-01-01     0   1153  1153. 발산역 1번, 9번 인근 대여소    정기권  NaN   20대     1
#   3  2025-01-01     0   1260      1260. 방이동 한양3차아파트 옆    정기권  NaN   20대     1
#   4  2025-01-01     0   1845      1845. 롯데캐슬골드파크1차 서문    정기권  NaN   20대     1
#
#         운동량   탄소량     이동거리
#   0  119.90  1.10  4730.80
#   1   24.46  0.30  1314.19
#   2   21.21  0.23   992.04
#   3   73.21  0.74  3187.35
#   4   53.80  0.48  2090.00  ,
#   6:          대여일자  대여시간   대여소번호 연령대코드  이용건수     이동거리                대여소
#   0  2025-01-01     0  3684.0  ~10대     1  4730.80       고덕자이(105동 앞)
#   1  2025-01-01     0  1044.0   20대     1  1314.19              굽은다리역
#   2  2025-01-01     0  1153.0   20대     1   992.04  발산역 1번, 9번 인근 대여소
#   3  2025-01-01     0  1260.0   20대     1  3187.35      방이동 한양3차아파트 옆
#   4  2025-01-01     0  1845.0   20대     1  2090.00      롯데캐슬골드파크1차 서문,
#   8:         대여일자  대여시간   대여소번호 연령대코드  이용건수     이동거리                대여소    연도  월  일
#   0 2025-01-01     0  3684.0  ~10대     1  4730.80       고덕자이(105동 앞)  2025  1  1
#   1 2025-01-01     0  1044.0   20대     1  1314.19              굽은다리역  2025  1  1
#   2 2025-01-01     0  1153.0   20대     1   992.04  발산역 1번, 9번 인근 대여소  2025  1  1
#   3 2025-01-01     0  1260.0   20대     1  3187.35      방이동 한양3차아파트 옆  2025  1  1
#   4 2025-01-01     0  1845.0   20대     1  2090.00      롯데캐슬골드파크1차 서문  2025  1  1,
#   9:          대여일자  대여시간  대여소번호                     대여소명 대여구분코드   성별 연령대코드  이용건수  \
#   0  2025-01-01     0   3684       3684. 고덕자이(105동 앞)    정기권  NaN  ~10대     1
#   1  2025-01-01     0   1044              1044. 굽은다리역    정기권  NaN   20대     1
#   2  2025-01-01     0   1153  1153. 발산역 1번, 9번 인근 대여소    정기권  NaN   20대     1
#   3  2025-01-01     0   1260      1260. 방이동 한양3차아파트 옆    정기권  NaN   20대     1
#   4  2025-01-01     0   1845      1845. 롯데캐슬골드파크1차 서문    정기권  NaN   20대     1
#
#         운동량   탄소량     이동거리
#   0  119.90  1.10  4730.80
#   1   24.46  0.30  1314.19
#   2   21.21  0.23   992.04
#   3   73.21  0.74  3187.35
#   4   53.80  0.48  2090.00  ,
#   12:          대여일자  대여시간   대여소번호                     대여소명 대여구분코드   성별 연령대코드  이용건수  \
#   0  2025-01-01     0  3684.0       3684. 고덕자이(105동 앞)    정기권  NaN  ~10대     1
#   1  2025-01-01     0  1044.0              1044. 굽은다리역    정기권  NaN   20대     1
#   2  2025-01-01     0  1153.0  1153. 발산역 1번, 9번 인근 대여소    정기권  NaN   20대     1
#   3  2025-01-01     0  1260.0      1260. 방이동 한양3차아파트 옆    정기권  NaN   20대     1
#   4  2025-01-01     0  1845.0      1845. 롯데캐슬골드파크1차 서문    정기권  NaN   20대     1
#
#         운동량   탄소량     이동거리                대여소
#   0  119.90  1.10  4730.80       고덕자이(105동 앞)
#   1   24.46  0.30  1314.19              굽은다리역
#   2   21.21  0.23   992.04  발산역 1번, 9번 인근 대여소
#   3   73.21  0.74  3187.35      방이동 한양3차아파트 옆
#   4   53.80  0.48  2090.00      롯데캐슬골드파크1차 서문  ,
#   14:      연도  월  일       대여일자  대여시간   대여소번호 연령대코드  이용건수     이동거리                대여소
#   0  2025  1  1 2025-01-01     0  3684.0  ~10대     1  4730.80       고덕자이(105동 앞)
#   1  2025  1  1 2025-01-01     0  1044.0   20대     1  1314.19              굽은다리역
#   2  2025  1  1 2025-01-01     0  1153.0   20대     1   992.04  발산역 1번, 9번 인근 대여소
#   3  2025  1  1 2025-01-01     0  1260.0   20대     1  3187.35      방이동 한양3차아파트 옆
#   4  2025  1  1 2025-01-01     0  1845.0   20대     1  2090.00      롯데캐슬골드파크1차 서문,
#   15:          대여일자  대여시간  대여소번호                     대여소명 대여구분코드   성별 연령대코드  이용건수  \
#   0  2025-01-01     0   3684       3684. 고덕자이(105동 앞)    정기권  NaN  ~10대     1
#   1  2025-01-01     0   1044              1044. 굽은다리역    정기권  NaN   20대     1
#   2  2025-01-01     0   1153  1153. 발산역 1번, 9번 인근 대여소    정기권  NaN   20대     1
#   3  2025-01-01     0   1260      1260. 방이동 한양3차아파트 옆    정기권  NaN   20대     1
#   4  2025-01-01     0   1845      1845. 롯데캐슬골드파크1차 서문    정기권  NaN   20대     1
#
#         운동량   탄소량     이동거리
#   0  119.90  1.10  4730.80
#   1   24.46  0.30  1314.19
#   2   21.21  0.23   992.04
#   3   73.21  0.74  3187.35
#   4   53.80  0.48  2090.00  ,
#   17:          대여일자  대여시간   대여소번호                     대여소명 대여구분코드   성별 연령대코드  이용건수  \
#   0  2025-01-01     0  3684.0       3684. 고덕자이(105동 앞)    정기권  NaN  ~10대     1
#   1  2025-01-01     0  1044.0              1044. 굽은다리역    정기권  NaN   20대     1
#   2  2025-01-01     0  1153.0  1153. 발산역 1번, 9번 인근 대여소    정기권  NaN   20대     1
#   3  2025-01-01     0  1260.0      1260. 방이동 한양3차아파트 옆    정기권  NaN   20대     1
#   4  2025-01-01     0  1845.0      1845. 롯데캐슬골드파크1차 서문    정기권  NaN   20대     1
#
#         운동량   탄소량     이동거리                대여소
#   0  119.90  1.10  4730.80       고덕자이(105동 앞)
#   1   24.46  0.30  1314.19              굽은다리역
#   2   21.21  0.23   992.04  발산역 1번, 9번 인근 대여소
#   3   73.21  0.74  3187.35      방이동 한양3차아파트 옆
#   4   53.80  0.48  2090.00      롯데캐슬골드파크1차 서문  ,
#   18:      연도  월  일  대여시간   대여소번호 연령대코드  이용건수     이동거리                대여소
#   0  2025  1  1     0  3684.0  ~10대     1  4730.80       고덕자이(105동 앞)
#   1  2025  1  1     0  1044.0   20대     1  1314.19              굽은다리역
#   2  2025  1  1     0  1153.0   20대     1   992.04  발산역 1번, 9번 인근 대여소
#   3  2025  1  1     0  1260.0   20대     1  3187.35      방이동 한양3차아파트 옆
#   4  2025  1  1     0  1845.0   20대     1  2090.00      롯데캐슬골드파크1차 서문,
#   19:      연도  월  일  대여시간  대여소번호 연령대코드  이용건수     이동거리                대여소
#   0  2025  1  1     0   3684  ~10대     1  4730.80       고덕자이(105동 앞)
#   1  2025  1  1     0   1044   20대     1  1314.19              굽은다리역
#   2  2025  1  1     0   1153   20대     1   992.04  발산역 1번, 9번 인근 대여소
#   3  2025  1  1     0   1260   20대     1  3187.35      방이동 한양3차아파트 옆
#   4  2025  1  1     0   1845   20대     1  2090.00      롯데캐슬골드파크1차 서문,
#   20: 연도       0
#   월        0
#   일        0
#   대여시간     0
#   대여소번호    1
#   연령대코드    0
#   이용건수     0
#   이동거리     0
#   대여소      1
#   dtype: int64,
#   22: 연도       0
#   월        0
#   일        0
#   대여시간     0
#   대여소번호    0
#   연령대코드    0
#   이용건수     0
#   이동거리     0
#   대여소      0
#   dtype: int64,
#   23:          대여일자  대여시간  대여소번호                     대여소명 대여구분코드   성별 연령대코드  이용건수  \
#   0  2025-01-01     0   3684       3684. 고덕자이(105동 앞)    정기권  NaN  ~10대     1
#   1  2025-01-01     0   1044              1044. 굽은다리역    정기권  NaN   20대     1
#   2  2025-01-01     0   1153  1153. 발산역 1번, 9번 인근 대여소    정기권  NaN   20대     1
#   3  2025-01-01     0   1260      1260. 방이동 한양3차아파트 옆    정기권  NaN   20대     1
#   4  2025-01-01     0   1845      1845. 롯데캐슬골드파크1차 서문    정기권  NaN   20대     1
#
#         운동량   탄소량     이동거리
#   0  119.90  1.10  4730.80
#   1   24.46  0.30  1314.19
#   2   21.21  0.23   992.04
#   3   73.21  0.74  3187.35
#   4   53.80  0.48  2090.00  ,
#   25: 대여일자           0
#   대여시간           0
#   대여소번호          0
#   대여소명           0
#   대여구분코드         0
#   성별        420294
#   연령대코드          0
#   이용건수           0
#   운동량         6237
#   탄소량         6237
#   이동거리           0
#   dtype: int64,
#   27:          대여일자  대여시간   대여소번호                     대여소명 대여구분코드   성별 연령대코드  이용건수  \
#   0  2025-01-01     0  3684.0       3684. 고덕자이(105동 앞)    정기권  NaN  ~10대     1
#   1  2025-01-01     0  1044.0              1044. 굽은다리역    정기권  NaN   20대     1
#   2  2025-01-01     0  1153.0  1153. 발산역 1번, 9번 인근 대여소    정기권  NaN   20대     1
#   3  2025-01-01     0  1260.0      1260. 방이동 한양3차아파트 옆    정기권  NaN   20대     1
#   4  2025-01-01     0  1845.0      1845. 롯데캐슬골드파크1차 서문    정기권  NaN   20대     1
#
#         운동량   탄소량     이동거리                대여소
#   0  119.90  1.10  4730.80       고덕자이(105동 앞)
#   1   24.46  0.30  1314.19              굽은다리역
#   2   21.21  0.23   992.04  발산역 1번, 9번 인근 대여소
#   3   73.21  0.74  3187.35      방이동 한양3차아파트 옆
#   4   53.80  0.48  2090.00      롯데캐슬골드파크1차 서문  ,
#   28: 대여일자           0
#   대여시간           0
#   대여소번호          1
#   대여소명           0
#   대여구분코드         0
#   성별        420294
#   연령대코드          0
#   이용건수           0
#   운동량         6237
#   탄소량         6237
#   이동거리           0
#   대여소            1
#   dtype: int64,
#   29:          대여일자  대여시간  대여소번호                     대여소명 대여구분코드   성별 연령대코드  이용건수  \
#   0  2025-01-01     0   3684       3684. 고덕자이(105동 앞)    정기권  NaN  ~10대     1
#   1  2025-01-01     0   1044              1044. 굽은다리역    정기권  NaN   20대     1
#   2  2025-01-01     0   1153  1153. 발산역 1번, 9번 인근 대여소    정기권  NaN   20대     1
#   3  2025-01-01     0   1260      1260. 방이동 한양3차아파트 옆    정기권  NaN   20대     1
#   4  2025-01-01     0   1845      1845. 롯데캐슬골드파크1차 서문    정기권  NaN   20대     1
#
#         운동량   탄소량     이동거리
#   0  119.90  1.10  4730.80
#   1   24.46  0.30  1314.19
#   2   21.21  0.23   992.04
#   3   73.21  0.74  3187.35
#   4   53.80  0.48  2090.00  ,
#   30: 대여일자           0
#   대여시간           0
#   대여소번호          0
#   대여소명           0
#   대여구분코드         0
#   성별        420294
#   연령대코드          0
#   이용건수           0
#   운동량         6237
#   탄소량         6237
#   이동거리           0
#   dtype: int64,
#   31: array(['AS센터'], dtype=object),
#   33:          대여일자  대여시간  대여소번호                     대여소명 대여구분코드   성별 연령대코드  이용건수  \
#   0  2025-01-01     0   3684       3684. 고덕자이(105동 앞)    정기권  NaN  ~10대     1
#   1  2025-01-01     0   1044              1044. 굽은다리역    정기권  NaN   20대     1
#   2  2025-01-01     0   1153  1153. 발산역 1번, 9번 인근 대여소    정기권  NaN   20대     1
#   3  2025-01-01     0   1260      1260. 방이동 한양3차아파트 옆    정기권  NaN   20대     1
#   4  2025-01-01     0   1845      1845. 롯데캐슬골드파크1차 서문    정기권  NaN   20대     1
#
#         운동량   탄소량     이동거리                대여소
#   0  119.90  1.10  4730.80       고덕자이(105동 앞)
#   1   24.46  0.30  1314.19              굽은다리역
#   2   21.21  0.23   992.04  발산역 1번, 9번 인근 대여소
#   3   73.21  0.74  3187.35      방이동 한양3차아파트 옆
#   4   53.80  0.48  2090.00      롯데캐슬골드파크1차 서문  ,
#   34: 대여일자           0
#   대여시간           0
#   대여소번호          0
#   대여소명           0
#   대여구분코드         0
#   성별        420294
#   연령대코드          0
#   이용건수           0
#   운동량         6237
#   탄소량         6237
#   이동거리           0
#   대여소            0
#   dtype: int64,
#   35: array(['AS센터'], dtype=object),
#   37:          대여일자  대여시간  대여소번호                     대여소명 대여구분코드   성별 연령대코드  이용건수  \
#   0  2025-01-01     0   3684       3684. 고덕자이(105동 앞)    정기권  NaN  ~10대     1
#   1  2025-01-01     0   1044              1044. 굽은다리역    정기권  NaN   20대     1
#   2  2025-01-01     0   1153  1153. 발산역 1번, 9번 인근 대여소    정기권  NaN   20대     1
#   3  2025-01-01     0   1260      1260. 방이동 한양3차아파트 옆    정기권  NaN   20대     1
#   4  2025-01-01     0   1845      1845. 롯데캐슬골드파크1차 서문    정기권  NaN   20대     1
#
#         운동량   탄소량     이동거리
#   0  119.90  1.10  4730.80
#   1   24.46  0.30  1314.19
#   2   21.21  0.23   992.04
#   3   73.21  0.74  3187.35
#   4   53.80  0.48  2090.00  ,
#   38: 대여일자           0
#   대여시간           0
#   대여소번호          0
#   대여소명           0
#   대여구분코드         0
#   성별        420294
#   연령대코드          0
#   이용건수           0
#   운동량         6237
#   탄소량         6237
#   이동거리           0
#   dtype: int64,
#   39: array(['AS센터'], dtype=object),
#   41:          대여일자  대여시간  대여소번호                     대여소명 대여구분코드   성별 연령대코드  이용건수  \
#   0  2025-01-01     0   3684       3684. 고덕자이(105동 앞)    정기권  NaN  ~10대     1
#   1  2025-01-01     0   1044              1044. 굽은다리역    정기권  NaN   20대     1
#   2  2025-01-01     0   1153  1153. 발산역 1번, 9번 인근 대여소    정기권  NaN   20대     1
#   3  2025-01-01     0   1260      1260. 방이동 한양3차아파트 옆    정기권  NaN   20대     1
#   4  2025-01-01     0   1845      1845. 롯데캐슬골드파크1차 서문    정기권  NaN   20대     1
#
#         운동량   탄소량     이동거리                대여소
#   0  119.90  1.10  4730.80       고덕자이(105동 앞)
#   1   24.46  0.30  1314.19              굽은다리역
#   2   21.21  0.23   992.04  발산역 1번, 9번 인근 대여소
#   3   73.21  0.74  3187.35      방이동 한양3차아파트 옆
#   4   53.80  0.48  2090.00      롯데캐슬골드파크1차 서문  ,
#   42: 대여일자           0
#   대여시간           0
#   대여소번호          0
#   대여소명           0
#   대여구분코드         0
#   성별        420294
#   연령대코드          0
#   이용건수           0
#   운동량         6237
#   탄소량         6237
#   이동거리           0
#   대여소            0
#   dtype: int64,
#   43: array(['AS센터'], dtype=object),
#   44:          대여일자  대여시간  대여소번호                     대여소명 대여구분코드   성별 연령대코드  이용건수  \
#   0  2025-01-01     0   3684       3684. 고덕자이(105동 앞)    정기권  NaN  ~10대     1
#   1  2025-01-01     0   1044              1044. 굽은다리역    정기권  NaN   20대     1
#   2  2025-01-01     0   1153  1153. 발산역 1번, 9번 인근 대여소    정기권  NaN   20대     1
#   3  2025-01-01     0   1260      1260. 방이동 한양3차아파트 옆    정기권  NaN   20대     1
#   4  2025-01-01     0   1845      1845. 롯데캐슬골드파크1차 서문    정기권  NaN   20대     1
#
#         운동량   탄소량     이동거리                대여소
#   0  119.90  1.10  4730.80       고덕자이(105동 앞)
#   1   24.46  0.30  1314.19              굽은다리역
#   2   21.21  0.23   992.04  발산역 1번, 9번 인근 대여소
#   3   73.21  0.74  3187.35      방이동 한양3차아파트 옆
#   4   53.80  0.48  2090.00      롯데캐슬골드파크1차 서문  ,
#   45:          대여일자  대여시간  대여소번호                     대여소명 대여구분코드   성별 연령대코드  이용건수  \
#   0  2025-01-01     0   3684       3684. 고덕자이(105동 앞)    정기권  NaN  ~10대     1
#   1  2025-01-01     0   1044              1044. 굽은다리역    정기권  NaN   20대     1
#   2  2025-01-01     0   1153  1153. 발산역 1번, 9번 인근 대여소    정기권  NaN   20대     1
#   3  2025-01-01     0   1260      1260. 방이동 한양3차아파트 옆    정기권  NaN   20대     1
#   4  2025-01-01     0   1845      1845. 롯데캐슬골드파크1차 서문    정기권  NaN   20대     1
#
#         운동량   탄소량     이동거리
#   0  119.90  1.10  4730.80
#   1   24.46  0.30  1314.19
#   2   21.21  0.23   992.04
#   3   73.21  0.74  3187.35
#   4   53.80  0.48  2090.00  ,
#   46: 대여일자           0
#   대여시간           0
#   대여소번호          0
#   대여소명           0
#   대여구분코드         0
#   성별        420294
#   연령대코드          0
#   이용건수           0
#   운동량         6237
#   탄소량         6237
#   이동거리           0
#   dtype: int64,
#   47: array(['AS센터'], dtype=object),
#   49:          대여일자  대여시간  대여소번호                     대여소명 대여구분코드   성별 연령대코드  이용건수  \
#   0  2025-01-01     0   3684       3684. 고덕자이(105동 앞)    정기권  NaN  ~10대     1
#   1  2025-01-01     0   1044              1044. 굽은다리역    정기권  NaN   20대     1
#   2  2025-01-01     0   1153  1153. 발산역 1번, 9번 인근 대여소    정기권  NaN   20대     1
#   3  2025-01-01     0   1260      1260. 방이동 한양3차아파트 옆    정기권  NaN   20대     1
#   4  2025-01-01     0   1845      1845. 롯데캐슬골드파크1차 서문    정기권  NaN   20대     1
#
#         운동량   탄소량     이동거리                대여소
#   0  119.90  1.10  4730.80       고덕자이(105동 앞)
#   1   24.46  0.30  1314.19              굽은다리역
#   2   21.21  0.23   992.04  발산역 1번, 9번 인근 대여소
#   3   73.21  0.74  3187.35      방이동 한양3차아파트 옆
#   4   53.80  0.48  2090.00      롯데캐슬골드파크1차 서문  ,
#   50: 대여일자           0
#   대여시간           0
#   대여소번호          0
#   대여소명           0
#   대여구분코드         0
#   성별        420294
#   연령대코드          0
#   이용건수           0
#   운동량         6237
#   탄소량         6237
#   이동거리           0
#   대여소            0
#   dtype: int64,
#   51: array(['AS센터'], dtype=object),
#   54:          대여일자  대여시간  대여소번호                     대여소명 대여구분코드   성별 연령대코드  이용건수  \
#   0  2025-01-01     0    NaN       3684. 고덕자이(105동 앞)    정기권  NaN  ~10대     1
#   1  2025-01-01     0    NaN              1044. 굽은다리역    정기권  NaN   20대     1
#   2  2025-01-01     0    NaN  1153. 발산역 1번, 9번 인근 대여소    정기권  NaN   20대     1
#   3  2025-01-01     0    NaN      1260. 방이동 한양3차아파트 옆    정기권  NaN   20대     1
#   4  2025-01-01     0    NaN      1845. 롯데캐슬골드파크1차 서문    정기권  NaN   20대     1
#
#         운동량   탄소량     이동거리  대여소
#   0  119.90  1.10  4730.80  NaN
#   1   24.46  0.30  1314.19  NaN
#   2   21.21  0.23   992.04  NaN
#   3   73.21  0.74  3187.35  NaN
#   4   53.80  0.48  2090.00  NaN  ,
#   55:          대여일자  대여시간  대여소번호                     대여소명 대여구분코드   성별 연령대코드  이용건수  \
#   0  2025-01-01     0   3684       3684. 고덕자이(105동 앞)    정기권  NaN  ~10대     1
#   1  2025-01-01     0   1044              1044. 굽은다리역    정기권  NaN   20대     1
#   2  2025-01-01     0   1153  1153. 발산역 1번, 9번 인근 대여소    정기권  NaN   20대     1
#   3  2025-01-01     0   1260      1260. 방이동 한양3차아파트 옆    정기권  NaN   20대     1
#   4  2025-01-01     0   1845      1845. 롯데캐슬골드파크1차 서문    정기권  NaN   20대     1
#
#         운동량   탄소량     이동거리
#   0  119.90  1.10  4730.80
#   1   24.46  0.30  1314.19
#   2   21.21  0.23   992.04
#   3   73.21  0.74  3187.35
#   4   53.80  0.48  2090.00  ,
#   56: 대여일자           0
#   대여시간           0
#   대여소번호          0
#   대여소명           0
#   대여구분코드         0
#   성별        420294
#   연령대코드          0
#   이용건수           0
#   운동량         6237
#   탄소량         6237
#   이동거리           0
#   dtype: int64,
#   57: array(['AS센터'], dtype=object),
#   60:          대여일자  대여시간   대여소번호                     대여소명 대여구분코드   성별 연령대코드  이용건수  \
#   0  2025-01-01     0  3684.0       3684. 고덕자이(105동 앞)    정기권  NaN  ~10대     1
#   1  2025-01-01     0  1044.0              1044. 굽은다리역    정기권  NaN   20대     1
#   2  2025-01-01     0  1153.0  1153. 발산역 1번, 9번 인근 대여소    정기권  NaN   20대     1
#   3  2025-01-01     0  1260.0      1260. 방이동 한양3차아파트 옆    정기권  NaN   20대     1
#   4  2025-01-01     0  1845.0      1845. 롯데캐슬골드파크1차 서문    정기권  NaN   20대     1
#
#         운동량   탄소량     이동거리                대여소
#   0  119.90  1.10  4730.80       고덕자이(105동 앞)
#   1   24.46  0.30  1314.19              굽은다리역
#   2   21.21  0.23   992.04  발산역 1번, 9번 인근 대여소
#   3   73.21  0.74  3187.35      방이동 한양3차아파트 옆
#   4   53.80  0.48  2090.00      롯데캐슬골드파크1차 서문  ,
#   61: 대여일자           0
#   대여시간           0
#   대여소번호          1
#   대여소명           0
#   대여구분코드         0
#   성별        420294
#   연령대코드          0
#   이용건수           0
#   운동량         6237
#   탄소량         6237
#   이동거리           0
#   대여소            1
#   dtype: int64,
#   62: 대여일자           0
#   대여시간           0
#   대여소번호          1
#   대여소명           0
#   대여구분코드         0
#   성별        420294
#   연령대코드          0
#   이용건수           0
#   운동량         6237
#   탄소량         6237
#   이동거리           0
#   대여소            1
#   dtype: int64,
#   63:      연도  월  일  대여시간   대여소번호 연령대코드  이용건수     이동거리                대여소
#   0  2025  1  1     0  3684.0  ~10대     1  4730.80       고덕자이(105동 앞)
#   1  2025  1  1     0  1044.0   20대     1  1314.19              굽은다리역
#   2  2025  1  1     0  1153.0   20대     1   992.04  발산역 1번, 9번 인근 대여소
#   3  2025  1  1     0  1260.0   20대     1  3187.35      방이동 한양3차아파트 옆
#   4  2025  1  1     0  1845.0   20대     1  2090.00      롯데캐슬골드파크1차 서문,
#   64:      연도  월  일  대여시간  대여소번호 연령대코드  이용건수     이동거리                대여소
#   0  2025  1  1     0   3684  ~10대     1  4730.80       고덕자이(105동 앞)
#   1  2025  1  1     0   1044   20대     1  1314.19              굽은다리역
#   2  2025  1  1     0   1153   20대     1   992.04  발산역 1번, 9번 인근 대여소
#   3  2025  1  1     0   1260   20대     1  3187.35      방이동 한양3차아파트 옆
#   4  2025  1  1     0   1845   20대     1  2090.00      롯데캐슬골드파크1차 서문,
#   65: 연도       0
#   월        0
#   일        0
#   대여시간     0
#   대여소번호    0
#   연령대코드    0
#   이용건수     0
#   이동거리     0
#   대여소      0
#   dtype: int64,
#   66:      연도  월  일  대여시간  대여소번호 연령대코드  이용건수     이동거리                대여소
#   0  2025  1  1     0   3684  ~10대     1  4730.80       고덕자이(105동 앞)
#   1  2025  1  1     0   1044   20대     1  1314.19              굽은다리역
#   2  2025  1  1     0   1153   20대     1   992.04  발산역 1번, 9번 인근 대여소
#   3  2025  1  1     0   1260   20대     1  3187.35      방이동 한양3차아파트 옆
#   4  2025  1  1     0   1845   20대     1  2090.00      롯데캐슬골드파크1차 서문,
#   67:      연도  월  일  대여시간  대여소번호 연령대코드  이용건수     이동거리                대여소
#   0  2025  1  1     0   3684  ~10대     1  4730.80       고덕자이(105동 앞)
#   1  2025  1  1     0   1044   20대     1  1314.19              굽은다리역
#   2  2025  1  1     0   1153   20대     1   992.04  발산역 1번, 9번 인근 대여소
#   3  2025  1  1     0   1260   20대     1  3187.35      방이동 한양3차아파트 옆
#   4  2025  1  1     0   1845   20대     1  2090.00      롯데캐슬골드파크1차 서문,
#   68: 연도    월  일   대여시간
#   2025  1  1   0       1575
#                1       1530
#                2       1230
#                3        841
#                4        718
#                        ...
#            31  19       912
#                20       775
#                21       819
#                22       947
#                23       730
#   Name: 이용건수, Length: 744, dtype: int64,
#   69:           연도  월   일  대여시간  대여소번호         대여소  이용건수
#   0       2025  1   1     0    102  망원역 1번출구 앞     2
#   1       2025  1   1     0    103  망원역 2번출구 앞     1
#   2       2025  1   1     0    104  합정역 1번출구 앞     1
#   3       2025  1   1     0    105  합정역 5번출구 앞     3
#   4       2025  1   1     0    107  신한은행 서교동지점     1
#   ...      ... ..  ..   ...    ...         ...   ...
#   790762  2025  1  31    23   5882         휴젠느     1
#   790763  2025  1  31    23   5883      영문초사거리     2
#   790764  2025  1  31    23   6053     중부세무서 앞     1
#   790765  2025  1  31    23   6055        한국경제     1
#   790766  2025  1  31    23   6171      월드빌딩 앞     2
#
#   [790767 rows x 7 columns],
#   70:      연도  월  일  대여시간  대여소번호         대여소  이용건수
#   0  2025  1  1     0    102  망원역 1번출구 앞     2
#   1  2025  1  1     0    103  망원역 2번출구 앞     1
#   2  2025  1  1     0    104  합정역 1번출구 앞     1
#   3  2025  1  1     0    105  합정역 5번출구 앞     3
#   4  2025  1  1     0    107  신한은행 서교동지점     1,
#   71:    연령대코드    이용건수
#   0    20대  415818
#   1    30대  464842
#   2    40대  292930
#   3    50대  224363
#   4    60대   87846
#   5  70대이상   17000
#   6   ~10대   89297
#   7     기타  112093,
#   72:          index    연도  월   일  대여시간  대여소번호                대여소  이용건수
#   0       163453  2025  1   7     8   2701      마곡나루역 5번출구 뒤편   105
#   1       513461  2025  1  20     8   2701      마곡나루역 5번출구 뒤편    99
#   2       370302  2025  1  15     8   2701      마곡나루역 5번출구 뒤편    97
#   3       399190  2025  1  16     8   2701      마곡나루역 5번출구 뒤편    97
#   4       317119  2025  1  13     8   2701      마곡나루역 5번출구 뒤편    95
#   ...        ...   ... ..  ..   ...    ...                ...   ...
# ...
#  2  2025-03-01     0   1251        1251. 석촌역 2번출구    정기권  NaN   20대     1
#  3  2025-03-01     0   1653         1653. 노원역1번출구    정기권  NaN   20대     1
#  4  2025-03-01     0   2376      2376. 수서역 6번출구 앞    정기권  NaN   20대     1
#
#        운동량   탄소량     이동거리
#  0   52.39  0.47  2035.25
#  1   29.14  0.30  1313.90
#  2    5.49  0.06   239.24
#  3   14.84  0.13   567.66
#  4  160.25  1.32  5699.54  ,
#  '_i115': "df1 = pd.read_csv('data/time/서울특별시 공공자전거 이용정보(시간대별)_202504.csv')\ndf1.head()",
#  '_115':          대여일자  대여시간  대여소번호                 대여소명 대여구분코드   성별 연령대코드  이용건수  \
#  0  2025-04-01     0   1044          1044. 굽은다리역    정기권  NaN   20대     1
#  1  2025-04-01     0   1651  1651. 상계동 우방유쉘아파트 앞    정기권  NaN   20대     1
#  2  2025-04-01     0   1336         1336. 성북3교 위    정기권  NaN   20대     1
#  3  2025-04-01     0   1158       1158. 가양역 8번출구    정기권  NaN   20대     1
#  4  2025-04-01     0   1160    1160. 양천향교역 7번출구앞    정기권  NaN   20대     1
#
#       운동량   탄소량     이동거리
#  0  42.41  0.35  1530.00
#  1  19.69  0.23   994.35
#  2  56.26  0.52  2220.00
#  3  24.89  0.23   982.10
#  4  17.35  0.14   617.01  ,
#  '_i116': "df1 = pd.read_csv('data/time/서울특별시 공공자전거 이용정보(시간대별)_202505.csv')\ndf1.head()",
#  '_116':          대여일자  대여시간  대여소번호                     대여소명 대여구분코드   성별 연령대코드  이용건수  \
#  0  2025-05-01     0    743      743. 현대6차아파트 101동 옆    정기권  NaN   20대     1
#  1  2025-05-01     0   1153  1153. 발산역 1번, 9번 인근 대여소    정기권  NaN   20대     3
#  2  2025-05-01     0   1643         1643. 태릉입구역 8번출구    정기권  NaN   20대     1
#  3  2025-05-01     0   1656       1656. 중앙하이츠 아파트 입구    정기권  NaN   20대     1
#  4  2025-05-01     0   1719       1719. 신도봉사거리 버스정류장    정기권  NaN   20대     1
#
#       운동량   탄소량     이동거리
#  0   0.00  0.00     0.00
#  1  74.93  0.68  2977.69
#  2  61.46  0.45  1940.15
#  3  39.90  0.49  2099.11
#  4  71.24  0.60  2570.00  ,
#  '_i117': "df1 = pd.read_csv('data/time/서울특별시 공공자전거 이용정보(시간대별)_202506.csv')\ndf1.head()",
#  '_117':          대여일자  대여시간  대여소번호                     대여소명 대여구분코드   성별 연령대코드  이용건수  \
#  0  2025-06-01     0   1153  1153. 발산역 1번, 9번 인근 대여소    정기권  NaN  ~10대     1
#  1  2025-06-01     0    949         949. 연신내역 1번 출구     정기권  NaN   20대     1
#  2  2025-06-01     0   1029              1029. 성내어울터    정기권  NaN   20대     2
#  3  2025-06-01     0   1150           1150. 송정역 1번출구    정기권  NaN   20대     2
#  4  2025-06-01     0    511        511. 서울숲역 5번 출구 옆    정기권  NaN   20대     1
#
#       운동량   탄소량     이동거리
#  0  15.86  0.14   616.00
#  1  35.78  0.32  1390.00
#  2  84.72  0.88  3780.26
#  3  84.98  0.59  2552.56
#  4  85.20  0.77  3310.00  ,
#  '_i118': "df1 = pd.read_csv('data/time/서울특별시 공공자전거 이용정보(시간대별)_202507.csv')\ndf1.head()",
#  '_118':          대여일자  대여시간  대여소번호                 대여소명 대여구분코드   성별 연령대코드  이용건수  \
#  0  2025-07-01     0   1293    1293. 석촌호수 서호 사거리    정기권  NaN  ~10대     1
#  1  2025-07-01     0    739           739. 신월사거리    정기권  NaN   20대     1
#  2  2025-07-01     0    505  505. 자양사거리 광진아크로텔 앞    정기권  NaN   20대     2
#  3  2025-07-01     0   1529     1529. 미아동 한국전력공사    정기권  NaN   20대     1
#  4  2025-07-01     0   1650        1650. 중계근린공원내    정기권  NaN   20대     2
#
#       운동량   탄소량  이동거리(M)  이용시간(분)
#  0  15.83  0.14   615.10        5
#  1   9.81  0.09   381.15        4
#  2  31.36  0.33  1393.80        8
#  3  79.58  0.72  3091.62       16
#  4  76.78  0.69  2982.88       38  ,
#  '_i119': 'import pandas as pd\n\ndf_list = []\n\nfor month in range(1, 7):\n    file = f"data/time/서울특별시 공공자전거 이용정보(시간대별)_2025{month:02d}.csv"\n\n    df = pd.read_csv(file)\n\n    # 대여소번호, 대여소 분리\n    df[[\'대여소번호\', \'대여소\']] = df[\'대여소명\'].str.extract(\n        r\'^(\\d+)\\.\\s*(.*)$\'\n    )\n\n    df[\'대여소번호\'] = pd.to_numeric(df[\'대여소번호\'], errors=\'coerce\')\n    df[\'대여소\'] = df[\'대여소\'].str.strip()\n\n    # 날짜 처리\n    df[\'대여일자\'] = pd.to_datetime(df[\'대여일자\'], errors=\'coerce\')\n    df[\'연도\'] = df[\'대여일자\'].dt.year\n    df[\'월\'] = df[\'대여일자\'].dt.month\n    df[\'일\'] = df[\'대여일자\'].dt.day\n\n    # 컬럼 순서 변경\n    cols = [\'연도\', \'월\', \'일\'] + [\n        col for col in df.columns if col not in [\'연도\', \'월\', \'일\']\n    ]\n    df = df[cols]\n\n    # 불필요한 컬럼 삭제\n    df = df.drop(\n        [\'대여소명\', \'대여일자\', \'대여구분코드\', \'성별\', \'운동량\', \'탄소량\'],\n        axis=1\n    )\n\n    df[\'대여소번호\'] = df[\'대여소번호\'].astype(\'Int64\')\n    df = df.dropna(subset=[\'대여소번호\'])\n\n    df_list.append(df)\n\n# 모든 월 합치기\ndf_up = pd.concat(df_list, ignore_index=True)\n\n# 월별 이용건수 합계\n# df_top = (\n#     df_all.groupby([\'연도\', \'월\', \'대여소번호\', \'대여소\', \'연령대코드\', \'이동거리\'], as_index=False)[\'이용건수\']\n#     .sum()\n#     .reset_index(drop=True)\n# )\n\ndf_up.head(20)',
#  'df_up':             연도  월   일  대여시간  대여소번호 연령대코드  이용건수      이동거리                 대여소
#  0         2025  1   1     0   3684  ~10대     1   4730.80        고덕자이(105동 앞)
#  1         2025  1   1     0   1044   20대     1   1314.19               굽은다리역
#  2         2025  1   1     0   1153   20대     1    992.04   발산역 1번, 9번 인근 대여소
#  3         2025  1   1     0   1260   20대     1   3187.35       방이동 한양3차아파트 옆
#  4         2025  1   1     0   1845   20대     1   2090.00       롯데캐슬골드파크1차 서문
#  ...        ... ..  ..   ...    ...   ...   ...       ...                 ...
#  15452120  2025  6  30    23   1914    기타     1   1598.10             대림역4번출구
#  15452121  2025  6  30    23   2264    기타     1    826.25            이수역 1번출구
#  15452122  2025  6  30    23    502    기타     1    848.18  자양(뚝섬한강공원)역 1번출구 앞
#  15452123  2025  6  30    23   1733  ~10대     1   1731.25       방학사거리 (봄마당 앞)
#  15452124  2025  6  30    23    565  ~10대     2  15587.89            옥수역 3번출구
#
#  [15452125 rows x 9 columns],
#  '_119':       연도  월  일  대여시간  대여소번호 연령대코드  이용건수     이동거리                대여소
#  0   2025  1  1     0   3684  ~10대     1  4730.80       고덕자이(105동 앞)
#  1   2025  1  1     0   1044   20대     1  1314.19              굽은다리역
#  2   2025  1  1     0   1153   20대     1   992.04  발산역 1번, 9번 인근 대여소
#  3   2025  1  1     0   1260   20대     1  3187.35      방이동 한양3차아파트 옆
#  4   2025  1  1     0   1845   20대     1  2090.00      롯데캐슬골드파크1차 서문
#  5   2025  1  1     0   1338   20대     1  2840.00             용문2교 옆
#  6   2025  1  1     0   1725   20대     1   700.00            창1동주민센터
#  7   2025  1  1     0   1452   20대     1  1436.47            겸재교 진입부
#  8   2025  1  1     0   1278   20대     1  2273.58           송파구청 교차로
#  9   2025  1  1     0   1543   20대     1  1370.00          수유1동 주민센터
#  10  2025  1  1     0   1364   20대     1  1780.00         성북동 치안센터 앞
#  11  2025  1  1     0    335   20대     1  1497.44      종로3가역 15번출구 앞
#  12  2025  1  1     0   1174   20대     1  2260.00      강서구청사거리(부민병원)
#  13  2025  1  1     0   1293   20대     1   710.00        석촌호수 서호 사거리
#  14  2025  1  1     0   1741   20대     1  1172.46           제일강산수산입구
#  15  2025  1  1     0   1184   20대     1  1650.00             마곡13단지
#  16  2025  1  1     0   2701   20대     1  1284.90      마곡나루역 5번출구 뒤편
#  17  2025  1  1     0    765   20대     1  1763.04          오목교역 3번출구
#  18  2025  1  1     0    472   20대     2  7712.51       삼일교(시그니쳐 타워)
#  19  2025  1  1     0    475   20대     1   577.36            DDP 패션몰,
#  '_i120': 'import pandas as pd\n\ndf_list = []\n\nfor month in range(1, 7):\n    file = f"data/time/서울특별시 공공자전거 이용정보(시간대별)_2025{month:02d}.csv"\n\n    df = pd.read_csv(file)\n\n    # 대여소번호, 대여소 분리\n    df[[\'대여소번호\', \'대여소\']] = df[\'대여소명\'].str.extract(\n        r\'^(\\d+)\\.\\s*(.*)$\'\n    )\n\n    df[\'대여소번호\'] = pd.to_numeric(df[\'대여소번호\'], errors=\'coerce\')\n    df[\'대여소\'] = df[\'대여소\'].str.strip()\n\n    # 날짜 처리\n    df[\'대여일자\'] = pd.to_datetime(df[\'대여일자\'], errors=\'coerce\')\n    df[\'연도\'] = df[\'대여일자\'].dt.year\n    df[\'월\'] = df[\'대여일자\'].dt.month\n    df[\'일\'] = df[\'대여일자\'].dt.day\n\n    # 컬럼 순서 변경\n    cols = [\'연도\', \'월\', \'일\'] + [\n        col for col in df.columns if col not in [\'연도\', \'월\', \'일\']\n    ]\n    df = df[cols]\n\n    # 불필요한 컬럼 삭제\n    df = df.drop(\n        [\'대여소명\', \'대여일자\', \'대여구분코드\', \'성별\', \'운동량\', \'탄소량\'],\n        axis=1\n    )\n\n    df[\'대여소번호\'] = df[\'대여소번호\'].astype(\'Int64\')\n    df = df.dropna(subset=[\'대여소번호\'])\n\n    df_list.append(df)\n\n# 모든 월 합치기\ndf_up = pd.concat(df_list, ignore_index=True)\n\n# 월별 이용건수 합계\n# df_top = (\n#     df_all.groupby([\'연도\', \'월\', \'대여소번호\', \'대여소\', \'연령대코드\', \'이동거리\'], as_index=False)[\'이용건수\']\n#     .sum()\n#     .reset_index(drop=True)\n# )\n\ndf_up.head(20)',
#  '_120':       연도  월  일  대여시간  대여소번호 연령대코드  이용건수     이동거리                대여소
#  0   2025  1  1     0   3684  ~10대     1  4730.80       고덕자이(105동 앞)
#  1   2025  1  1     0   1044   20대     1  1314.19              굽은다리역
#  2   2025  1  1     0   1153   20대     1   992.04  발산역 1번, 9번 인근 대여소
#  3   2025  1  1     0   1260   20대     1  3187.35      방이동 한양3차아파트 옆
#  4   2025  1  1     0   1845   20대     1  2090.00      롯데캐슬골드파크1차 서문
#  5   2025  1  1     0   1338   20대     1  2840.00             용문2교 옆
#  6   2025  1  1     0   1725   20대     1   700.00            창1동주민센터
#  7   2025  1  1     0   1452   20대     1  1436.47            겸재교 진입부
#  8   2025  1  1     0   1278   20대     1  2273.58           송파구청 교차로
#  9   2025  1  1     0   1543   20대     1  1370.00          수유1동 주민센터
#  10  2025  1  1     0   1364   20대     1  1780.00         성북동 치안센터 앞
#  11  2025  1  1     0    335   20대     1  1497.44      종로3가역 15번출구 앞
#  12  2025  1  1     0   1174   20대     1  2260.00      강서구청사거리(부민병원)
#  13  2025  1  1     0   1293   20대     1   710.00        석촌호수 서호 사거리
#  14  2025  1  1     0   1741   20대     1  1172.46           제일강산수산입구
#  15  2025  1  1     0   1184   20대     1  1650.00             마곡13단지
#  16  2025  1  1     0   2701   20대     1  1284.90      마곡나루역 5번출구 뒤편
#  17  2025  1  1     0    765   20대     1  1763.04          오목교역 3번출구
#  18  2025  1  1     0    472   20대     2  7712.51       삼일교(시그니쳐 타워)
#  19  2025  1  1     0    475   20대     1   577.36            DDP 패션몰,
#  '_i121': 'import pandas as pd',
#  '_i122': "for month in range(1, 7):\n    \n    # 파일 경로\n    file = f'data/time/서울특별시 공공자전거 이용정보(시간대별)_2025{month:02d}.csv'\n    \n    # CSV 불러오기\n    df = pd.read_csv(file)\n\n    # 대여소번호와 대여소 분리\n    df[['대여소번호', '대여소']] = df['대여소명'].str.extract(\n        r'^(\\d+)\\.\\s*(.*)$'\n    )\n\n    # 대여소번호 숫자 변환\n    df['대여소번호'] = pd.to_numeric(\n        df['대여소번호'],\n        errors='coerce'\n    )\n\n    # 대여소 이름 공백 제거\n    df['대여소'] = df['대여소'].str.strip()\n\n    # 날짜 변환\n    df['대여일자'] = pd.to_datetime(\n        df['대여일자'],\n        errors='coerce'\n    )\n\n    # 연도 / 월 / 일 분리\n    df['연도'] = df['대여일자'].dt.year\n    df['월'] = df['대여일자'].dt.month\n    df['일'] = df['대여일자'].dt.day\n\n    # 원하는 컬럼 순서\n    cols = ['연도', '월', '일'] + [\n        col for col in df.columns\n        if col not in ['연도', '월', '일']\n    ]\n\n    df = df[cols]\n\n    # 불필요한 컬럼 삭제\n    df = df.drop(\n        ['대여소명', '대여일자', '대여구분코드', '성별', '운동량', '탄소량'],\n        axis=1\n    )\n\n    # 대여소번호 정수형 변환\n    df['대여소번호'] = df['대여소번호'].astype('Int64')\n\n    # 대여소번호 결측치 제거\n    df = df.dropna(subset=['대여소번호'])\n\n    # # 대여소별 이용건수 합계\n    # df = (\n    #     df.groupby(\n    #         ['연도', '월', '대여소번호', '대여소'],\n    #         as_index=False\n    #     )['이용건수']\n    #     .sum()\n    #     .reset_index(drop=True)\n    # )\n\n    # df_202501, df_202502 ... 형태로 저장\n    globals()[f'df_2025{month:02d}'] = df",
#  '_i123': 'df_202501.head(10)',
#  '_123':      연도  월  일  대여시간  대여소번호 연령대코드  이용건수     이동거리                대여소
#  0  2025  1  1     0   3684  ~10대     1  4730.80       고덕자이(105동 앞)
#  1  2025  1  1     0   1044   20대     1  1314.19              굽은다리역
#  2  2025  1  1     0   1153   20대     1   992.04  발산역 1번, 9번 인근 대여소
#  3  2025  1  1     0   1260   20대     1  3187.35      방이동 한양3차아파트 옆
#  4  2025  1  1     0   1845   20대     1  2090.00      롯데캐슬골드파크1차 서문
#  5  2025  1  1     0   1338   20대     1  2840.00             용문2교 옆
#  6  2025  1  1     0   1725   20대     1   700.00            창1동주민센터
#  7  2025  1  1     0   1452   20대     1  1436.47            겸재교 진입부
#  8  2025  1  1     0   1278   20대     1  2273.58           송파구청 교차로
#  9  2025  1  1     0   1543   20대     1  1370.00          수유1동 주민센터,
#  '_i124': "df7 = pd.read_csv('/data/time/서울특별시 공공자전거 이용정보(시간대별)_202507.csv')\ndf7.head()",
#  '_i125': "df7 = pd.read_csv('/data/time/서울특별시 공공자전거 이용정보(시간대별)_202507.csv')\ndf7.head()",
#  '_i126': "df7 = pd.read_csv('data/time/서울특별시 공공자전거 이용정보(시간대별)_202507.csv')\ndf7.head()",
#  'df7':                대여일자  대여시간  대여소번호                  대여소명 대여구분코드   성별 연령대코드  \
#  0        2025-07-01     0   1293     1293. 석촌호수 서호 사거리    정기권  NaN  ~10대
#  1        2025-07-01     0    739            739. 신월사거리    정기권  NaN   20대
#  2        2025-07-01     0    505   505. 자양사거리 광진아크로텔 앞    정기권  NaN   20대
#  3        2025-07-01     0   1529      1529. 미아동 한국전력공사    정기권  NaN   20대
#  4        2025-07-01     0   1650         1650. 중계근린공원내    정기권  NaN   20대
#  ...             ...   ...    ...                   ...    ...  ...   ...
#  3222849  2025-07-31    23   1637  1637. KT 전화국 버스정류장 옆    정기권    M    기타
#  3222850  2025-07-31    23   1901      1901. 신도림동주민센터 앞    정기권    M    기타
#  3222851  2025-07-31    23   2102         2102. 봉림교 교통섬    정기권    M    기타
#  3222852  2025-07-31    23   2048       2048. 삼일초등학교 인근    정기권    M    기타
#  3222853  2025-07-31    23   2244      2244. 말죽거리공원 사거리    정기권    M    기타
#
#           이용건수    운동량   탄소량  이동거리(M)  이용시간(분)
#  0           1  15.83  0.14   615.10        5
#  1           1   9.81  0.09   381.15        4
#  2           2  31.36  0.33  1393.80        8
#  3           1  79.58  0.72  3091.62       16
#  4           2  76.78  0.69  2982.88       38
#  ...       ...    ...   ...      ...      ...
#  3222849     1  65.31  0.49  2114.27       12
#  3222850     1  45.71  0.46  1990.00       33
#  3222851     1  44.81  0.38  1616.58      107
#  3222852     1  30.09  0.30  1310.00        7
#  3222853     1  19.25  0.17   715.00        5
#
#  [3222854 rows x 12 columns],
#  '_126':          대여일자  대여시간  대여소번호                 대여소명 대여구분코드   성별 연령대코드  이용건수  \
#  0  2025-07-01     0   1293    1293. 석촌호수 서호 사거리    정기권  NaN  ~10대     1
#  1  2025-07-01     0    739           739. 신월사거리    정기권  NaN   20대     1
#  2  2025-07-01     0    505  505. 자양사거리 광진아크로텔 앞    정기권  NaN   20대     2
#  3  2025-07-01     0   1529     1529. 미아동 한국전력공사    정기권  NaN   20대     1
#  4  2025-07-01     0   1650        1650. 중계근린공원내    정기권  NaN   20대     2
#
#       운동량   탄소량  이동거리(M)  이용시간(분)
#  0  15.83  0.14   615.10        5
#  1   9.81  0.09   381.15        4
#  2  31.36  0.33  1393.80        8
#  3  79.58  0.72  3091.62       16
#  4  76.78  0.69  2982.88       38  ,
#  '_i127': "for month in range(7, 13):\n    \n    # 파일 경로\n    file = f'data/time/서울특별시 공공자전거 이용정보(시간대별)_2025{month:02d}.csv'\n    \n    # CSV 불러오기\n    df1 = pd.read_csv(file)\n\n    # 대여소번호와 대여소 분리\n    df1[['대여소번호', '대여소']] = df1['대여소명'].str.extract(\n        r'^(\\d+)\\.\\s*(.*)$'\n    )\n\n    # 대여소번호 숫자 변환\n    df1['대여소번호'] = pd.to_numeric(\n        df['대여소번호'],\n        errors='coerce'\n    )\n\n    # 대여소 이름 공백 제거\n    df1['대여소'] = df1['대여소'].str.strip()\n\n    # 날짜 변환\n    df1['대여일자'] = pd.to_datetime(\n        df1['대여일자'],\n        errors='coerce'\n    )\n\n    # 연도 / 월 / 일 분리\n    df1['연도'] = df1['대여일자'].dt.year\n    df1['월'] = df1['대여일자'].dt.month\n    df1['일'] = df1['대여일자'].dt.day\n\n    # 원하는 컬럼 순서\n    cols = ['연도', '월', '일'] + [\n        col for col in df1.columns\n        if col not in ['연도', '월', '일']\n    ]\n\n    df1 = df1[cols]\n\n    # 불필요한 컬럼 삭제\n    df1 = df1.drop(\n        ['대여소명', '대여일자', '대여구분코드', '성별', '운동량', '탄소량', '이용시간(분)'],\n        axis=1\n    )\n\n    # 대여소번호 정수형 변환\n    df1['대여소번호'] = df1['대여소번호'].astype('Int64')\n\n    # 대여소번호 결측치 제거\n    df1 = df1.dropna(subset=['대여소번호'])\n\n    # # 대여소별 이용건수 합계\n    # df = (\n    #     df.groupby(\n    #         ['연도', '월', '대여소번호', '대여소'],\n    #         as_index=False\n    #     )['이용건수']\n    #     .sum()\n    #     .reset_index(drop=True)\n    # )\n\n    # df_202501, df_202502 ... 형태로 저장\n    globals()[f'df_2025{month:02d}'] = df1",
#  '_i128': 'globals()'}
